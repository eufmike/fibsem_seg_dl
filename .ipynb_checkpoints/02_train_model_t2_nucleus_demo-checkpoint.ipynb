# %% [markdown]
# # Training Model
# 1. Keras & Tensorflow 2
# 2. hyper-parameter search
# 3. vanila-Unet: pull the hyper parameter setting out from the function of model
# 4. update: 04/21/2020
# 5. by Mike Chien-Cheng Shih

# %% [markdown]
# ## Load Dependencies
# * System managing modules: os, sys, glob, shutil
# * Array calculation: numpy
# * Image IO and processing: cv2, skimage, PIL
# * Visualization: matplotlib
# * Metadata handling: datetime, josn, pprint
# * Customized Functions:
#     1. `core.imageprep`
#     2. `core.models`
#     3. `core.metrics`

# %%
import os, sys
import itertools
import numpy as np

# image
from imutils import paths
import cv2
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk

# figure
import matplotlib.pyplot as plt

# metadata
import uuid
import json
from pprint import pprint
from datetime import datetime

# tensorflow
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau

# tensorboard
from tensorboard.plugins.hparams import api as hp

# customized function
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet, UNet_hp, vanilla_unet, vanilla_unet_nodrop
from core.metrics import iou_coef, dice_coef

# exported from vscode
from IPython import get_ipython
# %load_ext autoreload
get_ipython().run_line_magic('load_ext', 'autoreload')
# %autoreload 2
get_ipython().run_line_magic('autoreload', '2')
# %load_ext tensorboard
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %%
sys.executable
# Out:
# 'C:\\Users\\wucci_admin\\Anaconda3\\envs\\tfdl02\\python.exe'

# %% [markdown]
#  ## Load Training Dataset
#  * create image list `imgpath_all`

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# input set
# crop_input_set = '2020_01_23_09_51_20x'
crop_input_set = '2020_05_05_13_08_20x' # small training set

imginput = os.path.join('dl_seg_project_raw', 'data_crop', crop_input_set,)
imgpath = os.path.join(path, imginput)

print('input imgpath: {}'.format(imgpath))

img_dir = os.path.join(imgpath, 'images')
label_dir = os.path.join(imgpath, 'labels')

print('image dir: {}'.format(img_dir))
print('label dir: {}'.format(label_dir))

# check if the output folder exist. If not, create a folder
print('Generating output folders: ')
dir_checker('logs', path)
path_logs = os.path.join(path, 'logs')
dir_checker('fit', path_logs)
dir_checker('model', path_logs)
dir_checker('pars', path_logs)

# create input file list
imgpath_all = list(paths.list_images(img_dir))
# Out:
# Load Images...
# input imgpath: D:PerlmutterData\dl_seg_project_raw\data_crop\2020_05_05_13_08_20x
# image dir: D:PerlmutterData\dl_seg_project_raw\data_crop\2020_05_05_13_08_20x\images
# label dir: D:PerlmutterData\dl_seg_project_raw\data_crop\2020_05_05_13_08_20x\labels
# Generating output folders:
# logs exists in D:PerlmutterData
# fit exists in D:PerlmutterData\logs
# model exists in D:PerlmutterData\logs
# pars exists in D:PerlmutterData\logs

# %% [markdown]
#  ## Create Image Datagenerator
#  1. create only one datagen
#  2. specify valiation split in datagen argument
#  3. add split data when calling `datagen.flow_from_directory`

# %%
timestamp = datetime.now().strftime("%Y_%m_%d_%H_%M")
date =  datetime.now().strftime("%Y_%m_%d")
seed = 103
batch_size = 16
epoch = 20
validation_steps = 20
validation_split = 0.1
training_sample_size = len(imgpath_all)
IMG_HEIGHT = None
IMG_WIDTH = None
classes = ['cell_membrane', 'nucleus', 'autophagosome']
inputclass = [classes[1]]
learning_rate = 1e-4
loss = "binary_crossentropy"
metrics = ['accuracy', iou_coef, dice_coef]

metrics_name = []

# create a metrics name from str and function
for f in metrics:
    if callable(f):
        metrics_name.append(f.__name__)
    else:
        metrics_name.append(f)

print("Metrics: {}".format(metrics_name))
# Out:
# Metrics: ['accuracy', 'iou_coef', 'dice_coef']

# %% [markdown]
# ## Setup Data Generator

# %%
# create arguments for data generator
data_gen_img_args = dict(
                # featurewise_center = True,
                # featurewise_std_normalization = True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                rescale=1.0/255.0,
                )

data_gen_label_args = dict(
                # featurewise_center=True,
                # featurewise_std_normalization=True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                # rescale=1.0/255.0,
                rescale=1.0/255.0,
                )

# %% [markdown]
# ## Save Metadata
# * Save metadata includes timestamp, seed, batch size, and parameters of datagen.

# %%
# create parameter
pars = dict(
                # basic information
                timestamp = timestamp,
                date = date,
                seed = seed,
                batch_size = batch_size,
                
                # Data generator
                crop_input_set = crop_input_set,
                validation_steps = validation_steps,
                validation_split = validation_split,
                training_sample_size = training_sample_size,
                
                # training class
                classes = classes,
                inputclass = inputclass,
    
                # add datagen args
                data_gen_img_args = data_gen_img_args,
                data_gen_label_args = data_gen_label_args,
                
                # Build model
                IMG_HEIGHT = IMG_HEIGHT,
                IMG_WIDTH = IMG_WIDTH,
                epoch = epoch, 
                loss = loss,
                metrics_name = metrics_name,
                learning_rate = learning_rate,
                )

# save parameter
path_pars = os.path.join(path_logs, 'pars')
dir_checker(inputclass[0], path_pars)
dir_checker(date, os.path.join(path_pars, inputclass[0]))
pprint(pars)

# save pars
par_file_dir = os.path.join(path_pars, inputclass[0], date, 'pars_' + timestamp + '.json')
print(par_file_dir)

with open(par_file_dir, 'w') as outfile:
    json.dump(pars, outfile, indent=4)
# Out:
# nucleus exists in D:PerlmutterData\logs\pars
# 2020_05_15 does not exist in D:PerlmutterData\logs\pars\nucleus
# {'IMG_HEIGHT': None,
#  'IMG_WIDTH': None,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'crop_input_set': '2020_05_05_13_08_20x',
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.1,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.1,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'date': '2020_05_15',
#  'epoch': 20,
#  'inputclass': ['nucleus'],
#  'learning_rate': 0.0001,
#  'loss': 'binary_crossentropy',
#  'metrics_name': ['accuracy', 'iou_coef', 'dice_coef'],
#  'seed': 103,
#  'timestamp': '2020_05_15_14_58',
#  'training_sample_size': 6620,
#  'validation_split': 0.1,
#  'validation_steps': 20}
# D:PerlmutterData\logs\pars\nucleus\2020_05_15\pars_2020_05_15_14_58.json

# %% [markdown]
# ## Create Datagen
# Datagen does
# 1. images loading
# 2. on-the-fly data augmentation
# 3. create training and validation set

# %%
# create generator
image_datagen = ImageDataGenerator(**data_gen_img_args)
label_datagen = ImageDataGenerator(**data_gen_label_args)

# %%
# load images into generator
train_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training', # define subset as 'training'
    seed=seed)

train_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training',
    seed=seed)

valid_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation', # define subset as 'validation'
    seed=seed)

valid_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation',
    seed=seed)
# Out:
# Found 5958 images belonging to 1 classes.
# Found 5958 images belonging to 1 classes.
# Found 662 images belonging to 1 classes.
# Found 662 images belonging to 1 classes.

# %%
# merge image and label generator
def combine_generator(gen1, gen2):
    while True:
        yield(gen1.next(), gen2.next()) 
train_generator = combine_generator(train_image_generator, train_label_generator)
valid_generator = combine_generator(valid_image_generator, valid_label_generator)

# %% [markdown]
#  ## Training

# %%
print("Start training...")
# Out:
# Start training...

# %% [markdown]
#  ### Setup the model

# %%
# calculate steps_per_epoch
steps_per_epoch = training_sample_size * (1 - validation_split) // batch_size + 1
print("Steps per epoch: {}".format(steps_per_epoch))
# Out:
# Steps per epoch: 373.0

# %% [markdown]
# ## Hyperparameters Tuning
# 1. method: grid search
# 2. Hyperparameters: `learning_rate`, `dropout`, and `layers` of Unet
#     1. learning rate: 0.1, 0.01, 0.001, 0.0001
#     2. dropout: 0.5, 0.7
#     3. layers: 4, 5

# %%
# Create a .v2 file for saving hyperparameter and evaluation
# so we can see the results on tensorboard
hparamtuning_dir = os.path.join(path_logs, 'fit', inputclass[0], date, timestamp)

HP_LEARNINGRATE = hp.HParam('learning_rate', hp.Discrete([1e-2, 1e-3, 1e-4]))
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.5, 0.7]))
HP_LAYERS = hp.HParam('layers', hp.Discrete([4, 5]))

# hparams_list = [HP_DROPOUT, HP_LAYERS]

with tf.summary.create_file_writer(hparamtuning_dir).as_default():
    hp.hparams_config(
        hparams=[HP_LEARNINGRATE, HP_DROPOUT, HP_LAYERS],
        metrics=[hp.Metric('accuracy', display_name='Accuracy'), 
                 hp.Metric('iou_coef', display_name='IoU_Coef'), # create container for customized metrics
                 hp.Metric('dice_coef', display_name='Dice_Coef')], # the same
    )

# %% [markdown]
# ## Parameters in DL
# * model: vanilla U-net
#     1. kernel_initializer = `'he_normal'`
#     2. activation = `'relu'`
#     3. padding = `'same'`
#     4. `BatchNormalization`
# * loss: `binary_crossentropy`
# * `num_classes = 1`
# * evaluation:
#     1. accuracy
#     2. IOU
#     3. DICE

# %%
def run(run_name, hparamtuning_dir, hparams):
    
    # checkpoint
    modelfilename = 'model_' + timestamp + '.h5'
    dir_checker(run_name, hparamtuning_dir)
    dir_checker('model', os.path.join(hparamtuning_dir, run_name))
    
    modelfile_path = os.path.join(hparamtuning_dir, run_name, 'model', modelfilename)
    checkpointer = ModelCheckpoint(filepath = modelfile_path, 
                                   monitor = 'val_accuracy', 
                                   mode = 'max', 
                                   verbose = 1, 
                                   save_best_only = True, 
                                  )

    # early stopping 
    early_stopping = EarlyStopping(monitor='val_loss',
                               patience=8,
                               verbose=1,
                               min_delta=1e-4)

    # learning rate adjustment
    reduceLR = ReduceLROnPlateau(monitor='val_loss',
                        factor=0.1,
                        patience=4,
                        verbose=1,
                        min_delta=1e-3,
                        cooldown = 2,
                        )

    # tensorboard ----------------------------------------------
    
    # file_writer = create_file_writer(os.path.join(path_logs, 'fit', inputclass[0], date, timestamp, "metrics"))
    # file_writer.set_as_default()

    metrics = ['accuracy', iou_coef, dice_coef]
    
    tensorboard_callback = TensorBoard(log_dir = os.path.join(hparamtuning_dir, run_name), 
                                       profile_batch = 0, 
                                       update_freq= 30,
                                       histogram_freq = 1
                                       )

    # compile callbacks
    # callbacks = [checkpointer, tensorboard_callback, early_stopping, reduceLR]
    callbacks = [checkpointer, reduceLR, tensorboard_callback]
    
    hparamtuning_runname_dir = os.path.join(hparamtuning_dir, run_name)
    
    
    with tf.summary.create_file_writer(hparamtuning_runname_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial

        # prepare the model -----------------------------------
        
        # load hyper-parameter
        learning_rate = float(hparams[HP_LEARNINGRATE])
        print('learning rate: {}'.format(learning_rate))
        
        dropout = float(hparams[HP_DROPOUT])
        print('dropout: {}'.format(dropout))
        
        num_layers = int(hparams[HP_LAYERS])
        print('num layers: {}'.format(num_layers))
        
        '''
        unetmodel = vanilla_unet_nodrop(
                            shape = (IMG_HEIGHT, IMG_WIDTH), 
                            dropout = dropout, 
                            num_layers = num_layers, 
                            lr = learning_rate, 
                            loss = loss,
                            metrics = metrics,
                            summary = False,
                           )
        '''
        unetmodel = sm_unet(
                    shape = (IMG_HEIGHT, IMG_WIDTH, 1), 
                    )
        
        
        # load model ------------------------------------------
        
        '''
        # load weight
        path_model = os.path.join('D:', 'PerlmutterData', 'logs', 'fit', 
                                'nucleus', 
                                '2020_02_05',
                                '2020_02_05_16_29',
                                'run-2',
                                'model',
                                'model_2020_02_05_16_29.h5',)
        
        unetmodel.load_weights(path_model)
        '''
        
        
        # train the model -------------------------------------
        unetmodel.fit_generator(
                            generator = train_generator, 
                            validation_data = valid_generator,
                            validation_steps = validation_steps,
                            steps_per_epoch = steps_per_epoch,
                            epochs = epoch,  
                            callbacks = callbacks,
                            verbose = 1, 
                            )
    
        _, accuracy, iou, dice,  = unetmodel.evaluate_generator(valid_generator, steps = 50, verbose=1)
        tf.summary.scalar('accuracy', accuracy, step = 1)
        tf.summary.scalar('iou_coef', iou, step = 1)
        tf.summary.scalar('dice_coef', dice, step = 1)
        
        # -----------------------------------------------------
        
        # clean memory
        K.clear_session()
        del unetmodel

# %%
#train the model
session_num = 0
for learning_rate in HP_LEARNINGRATE.domain.values:
    for dropout in HP_DROPOUT.domain.values:
        for layer in HP_LAYERS.domain.values:
            run_name = "run-{}".format(session_num)
            print('--- Starting trial: {}'.format(run_name))

            # create hyper-parameter
            hparams = {
                HP_LEARNINGRATE: learning_rate,
                HP_DROPOUT: dropout,
                HP_LAYERS: layer,
            }
            print(hparams)
            print({h.name: hparams[h] for h in hparams})

            # build model and traning
            run(run_name, hparamtuning_dir, hparams)

            session_num += 1
# Out:
# --- Starting trial: run-0
# {HParam(name='learning_rate', domain=Discrete([0.0001, 0.001, 0.01]), display_name=None, description=None): 0.0001, HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.5, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 4}
# {'learning_rate': 0.0001, 'dropout': 0.5, 'layers': 4}
# run-0 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-0
# learning rate: 0.0001
# dropout: 0.5
# num layers: 4
# Epoch 1/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.5730 - accuracy: 0.6867 - iou_coef: 0.1329 - dice_coef: 0.1983
# Epoch 00001: val_accuracy improved from -inf to 0.54887, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-0\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 419s 1s/step - loss: 0.5727 - accuracy: 0.6869 - iou_coef: 0.1327 - dice_coef: 0.1979 - val_loss: 1.3023 - val_accuracy: 0.5489 - val_iou_coef: 0.1294 - val_dice_coef: 0.1892
# Epoch 2/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.6898 - iou_coef: 0.1443 - dice_coef: 0.2109
# Epoch 00002: val_accuracy did not improve from 0.54887
# 373/373 [==============================] - 333s 894ms/step - loss: 0.5362 - accuracy: 0.6897 - iou_coef: 0.1443 - dice_coef: 0.2108 - val_loss: 0.8166 - val_accuracy: 0.5232 - val_iou_coef: 0.1527 - val_dice_coef: 0.2329
# Epoch 3/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.
20
# 372/373 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9919 - iou_coef: 0.5513 - dice_coef: 0.5630
# Epoch 00019: val_accuracy did not improve from 0.97047
# 373/373 [==============================] - 322s 863ms/step - loss: 0.0204 - accuracy: 0.9919 - iou_coef: 0.5513 - dice_coef: 0.5629 - val_loss: 0.1185 - val_accuracy: 0.9631 - val_iou_coef: 0.6398 - val_dice_coef: 0.6640
# Epoch 20/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9920 - iou_coef: 0.5452 - dice_coef: 0.5568
# Epoch 00020: val_accuracy did not improve from 0.97047
# 373/373 [==============================] - 321s 861ms/step - loss: 0.0205 - accuracy: 0.9920 - iou_coef: 0.5449 - dice_coef: 0.5564 - val_loss: 0.2086 - val_accuracy: 0.9407 - val_iou_coef: 0.5614 - val_dice_coef: 0.5936
# 50/50 [==============================] - 16s 313ms/step - loss: 0.2388 - accuracy: 0.9311 - iou_coef: 0.5920 - dice_coef: 0.6272
# --- Starting trial: run-1
# {HParam(name='learning_rate', domain=Discrete([0.0001, 0.001, 0.01]), display_name=None, description=None): 0.0001, HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.5, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 5}
# {'learning_rate': 0.0001, 'dropout': 0.5, 'layers': 5}
# run-1 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1
# learning rate: 0.0001
# dropout: 0.5
# num layers: 5
# Epoch 1/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.6485 - accuracy: 0.6870 - iou_coef: 0.1155 - dice_coef: 0.1787
# Epoch 00001: val_accuracy improved from -inf to 0.52038, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 428s 1s/step - loss: 0.6484 - accuracy: 0.6872 - iou_coef: 0.1155 - dice_coef: 0.1787 - val_loss: 0.7243 - val_accuracy: 0.5204 - val_iou_coef: 0.1895 - val_dice_coef: 0.2869
# Epoch 2/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.6274 - accuracy: 0.6907 - iou_coef: 0.1152 - dice_coef: 0.1789
# Epoch 00002: val_accuracy improved from 0.52038 to 0.52125, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 427s 1s/step - loss: 0.6274 - accuracy: 0.6906 - iou_coef: 0.1152 - dice_coef: 0.1789 - val_loss: 0.7352 - val_accuracy: 0.5213 - val_iou_coef: 0.1673 - val_dice_coef: 0.2589
# Epoch 3/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.6072 - accuracy: 0.6886 - iou_coef: 0.1226 - dice_coef: 0.1876
# Epoch 00003: val_accuracy improved from 0.52125 to 0.53497, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 427s 1s/step - loss: 0.6070 - accuracy: 0.6886 - iou_coef: 0.1226 - dice_coef: 0.1876 - val_loss: 0.7073 - val_accuracy: 0.5350 - val_iou_coef: 0.1867 - val_dice_coef: 0.2781
# Epoch 4/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.5334 - accuracy: 0.6880 - iou_coef: 0.1438 - dice_coef: 0.2100
# Epoch 00004: val_accuracy improved from 0.53497 to 0.54283, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 428s 1s/step - loss: 0.5338 - accuracy: 0.6878 - iou_coef: 0.1439 - dice_coef: 0.2102 - val_loss: 0.7736 - val_accuracy: 0.5428 - val_iou_coef: 0.1787 - val_dice_coef: 0.2595
# Epoch 5/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.5157 - accuracy: 0.6967 - iou_coef: 0.1460 - dice_coef: 0.2109
# Epoch 00005: val_accuracy improved from 0.54283 to 0.57142, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-1\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 427s 1s/step - loss: 0.5157 - accuracy: 0.6966 - iou_coef: 0.1460 - dice_coef: 0.2109 - val_loss: 0.9289 - val_accuracy: 0.5714 - val_iou_coef: 0.1370 - val_dice_coef: 0.2008
# Epoch 6/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.
saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-2\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 324s 868ms/step - loss: 0.0755 - accuracy: 0.9719 - iou_coef: 0.3683 - dice_coef: 0.3907 - val_loss: 0.2210 - val_accuracy: 0.9113 - val_iou_coef: 0.4694 - val_dice_coef: 0.5167
# Epoch 18/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.0764 - accuracy: 0.9717 - iou_coef: 0.3681 - dice_coef: 0.3903
# Epoch 00018: val_accuracy improved from 0.91134 to 0.91287, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-2\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 323s 866ms/step - loss: 0.0765 - accuracy: 0.9716 - iou_coef: 0.3683 - dice_coef: 0.3906 - val_loss: 0.2320 - val_accuracy: 0.9129 - val_iou_coef: 0.4697 - val_dice_coef: 0.5159
# Epoch 19/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9739 - iou_coef: 0.3744 - dice_coef: 0.3962
# Epoch 00019: val_accuracy did not improve from 0.91287
# 373/373 [==============================] - 322s 864ms/step - loss: 0.0702 - accuracy: 0.9739 - iou_coef: 0.3742 - dice_coef: 0.3960 - val_loss: 0.6580 - val_accuracy: 0.8093 - val_iou_coef: 0.3660 - val_dice_coef: 0.4116
# Epoch 20/20
# 372/373 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9725 - iou_coef: 0.3638 - dice_coef: 0.3859
# Epoch 00020: val_accuracy did not improve from 0.91287
# 373/373 [==============================] - 322s 863ms/step - loss: 0.0758 - accuracy: 0.9725 - iou_coef: 0.3642 - dice_coef: 0.3862 - val_loss: 0.5177 - val_accuracy: 0.8437 - val_iou_coef: 0.3968 - val_dice_coef: 0.4443
# 50/50 [==============================] - 16s 313ms/step - loss: 0.5140 - accuracy: 0.8432 - iou_coef: 0.3977 - dice_coef: 0.4493
# --- Starting trial: run-3
# {HParam(name='learning_rate', domain=Discrete([0.0001, 0.001, 0.01]), display_name=None, description=None): 0.0001, HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.7, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 5}
# {'learning_rate': 0.0001, 'dropout': 0.7, 'layers': 5}
# run-3 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-3
# learning rate: 0.0001
# dropout: 0.7
# num layers: 5
# Epoch 1/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.6112 - accuracy: 0.6857 - iou_coef: 0.1262 - dice_coef: 0.1910
# Epoch 00001: val_accuracy improved from -inf to 0.54665, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-3\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 427s 1s/step - loss: 0.6111 - accuracy: 0.6856 - iou_coef: 0.1262 - dice_coef: 0.1911 - val_loss: 0.7319 - val_accuracy: 0.5466 - val_iou_coef: 0.1636 - val_dice_coef: 0.2445
# Epoch 2/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.5386 - accuracy: 0.7093 - iou_coef: 0.1468 - dice_coef: 0.2104
# Epoch 00002: val_accuracy did not improve from 0.54665
# 373/373 [==============================] - 423s 1s/step - loss: 0.5386 - accuracy: 0.7092 - iou_coef: 0.1468 - dice_coef: 0.2105 - val_loss: 0.7560 - val_accuracy: 0.5448 - val_iou_coef: 0.1678 - val_dice_coef: 0.2480
# Epoch 3/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.5198 - accuracy: 0.7132 - iou_coef: 0.1529 - dice_coef: 0.2161
# Epoch 00003: val_accuracy improved from 0.54665 to 0.54722, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-3\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 427s 1s/step - loss: 0.5191 - accuracy: 0.7138 - iou_coef: 0.1526 - dice_coef: 0.2157 - val_loss: 1.2871 - val_accuracy: 0.5472 - val_iou_coef: 0.0992 - val_dice_coef: 0.1472
# Epoch 4/20
# 372/373 [============================>.] - ETA: 1s - loss: 0.2756 - accuracy: 0.8879 - iou_coef: 0.2726 - dice_coef: 0.3129
# Epoch 00004: val_accuracy improved from 0.54722 to 0.69337, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-3\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 428s 1s/step - loss: 0
# {HParam(name='learning_rate', domain=Discrete([0.0001, 0.001, 0.01]), display_name=None, description=None): 0.001, HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.5, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 4}
# {'learning_rate': 0.001, 'dropout': 0.5, 'layers': 4}
# run-4 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-4
# learning rate: 0.001
# dropout: 0.5
# num layers: 4
# Epoch 1/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7642 - accuracy: 0.6898 - iou_coef: 0.5378 - dice_coef: 0.5380
# Epoch 00001: val_accuracy improved from -inf to 0.54123, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-4\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 323s 866ms/step - loss: 4.7713 - accuracy: 0.6893 - iou_coef: 0.5377 - dice_coef: 0.5379 - val_loss: 7.1356 - val_accuracy: 0.5412 - val_iou_coef: 0.3869 - val_dice_coef: 0.3869
# Epoch 2/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7769 - accuracy: 0.6900 - iou_coef: 0.5380 - dice_coef: 0.5380
# Epoch 00002: val_accuracy did not improve from 0.54123
# 373/373 [==============================] - 322s 865ms/step - loss: 4.7752 - accuracy: 0.6901 - iou_coef: 0.5381 - dice_coef: 0.5381 - val_loss: 7.4995 - val_accuracy: 0.5129 - val_iou_coef: 0.3596 - val_dice_coef: 0.3596
# Epoch 3/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7333 - accuracy: 0.6922 - iou_coef: 0.5387 - dice_coef: 0.5387
# Epoch 00003: val_accuracy did not improve from 0.54123
# 373/373 [==============================] - 322s 863ms/step - loss: 4.7358 - accuracy: 0.6921 - iou_coef: 0.5386 - dice_coef: 0.5386 - val_loss: 7.5207 - val_accuracy: 0.5160 - val_iou_coef: 0.3491 - val_dice_coef: 0.3491
# Epoch 4/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7550 - accuracy: 0.6908 - iou_coef: 0.5397 - dice_coef: 0.5397
# Epoch 00004: val_accuracy improved from 0.54123 to 0.55946, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-4\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 326s 873ms/step - loss: 4.7508 - accuracy: 0.6911 - iou_coef: 0.5399 - dice_coef: 0.5399 - val_loss: 6.7828 - val_accuracy: 0.5595 - val_iou_coef: 0.4005 - val_dice_coef: 0.4005
# Epoch 5/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7837 - accuracy: 0.6894 - iou_coef: 0.5375 - dice_coef: 0.5375
# Epoch 00005: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.7900 - accuracy: 0.6890 - iou_coef: 0.5371 - dice_coef: 0.5371 - val_loss: 6.9125 - val_accuracy: 0.5510 - val_iou_coef: 0.3972 - val_dice_coef: 0.3972
# Epoch 6/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7820 - accuracy: 0.6891 - iou_coef: 0.5384 - dice_coef: 0.5384
# Epoch 00006: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.7790 - accuracy: 0.6893 - iou_coef: 0.5381 - dice_coef: 0.5381 - val_loss: 7.2776 - val_accuracy: 0.5361 - val_iou_coef: 0.3616 - val_dice_coef: 0.3616
# Epoch 7/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7382 - accuracy: 0.6918 - iou_coef: 0.5408 - dice_coef: 0.5408
# Epoch 00007: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.7332 - accuracy: 0.6921 - iou_coef: 0.5407 - dice_coef: 0.5407 - val_loss: 7.1668 - val_accuracy: 0.5345 - val_iou_coef: 0.3695 - val_dice_coef: 0.3695
# Epoch 8/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.8128 - accuracy: 0.6873 - iou_coef: 0.5370 - dice_coef: 0.5370
# Epoch 00008: val_accuracy did not improve from 0.55946
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 373/373 [==============================] - 322s 864ms/step - loss: 4.8180 - accuracy: 0.6870 - iou_coef: 0.5366 - dice_coef: 0.5366 - val_loss: 7.2442 - val_accuracy: 0.5274 - val_iou_coef: 0.3786 - val_dice_coef: 0.3786
# Epoch 9/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7250 - accuracy: 0.6927 - iou_coef: 0.5413 - dice_coef: 0.5413
# Epoch 00009: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.7313 - accuracy: 0.6923 - iou_coef: 0.5408 - dice_coef: 0.5408 - val_loss: 7.2342 - val_accuracy: 0.5302 - val_iou_coef: 0.3816 - val_dice_coef: 0.3816
# Epoch 10/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.8024 - accuracy: 0.6886 - iou_coef: 0.5386 - dice_coef: 0.5386
# Epoch 00010: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.8123 - accuracy: 0.6879 - iou_coef: 0.5381 - dice_coef: 0.5381 - val_loss: 6.8852 - val_accuracy: 0.5419 - val_iou_coef: 0.3896 - val_dice_coef: 0.3896
# Epoch 11/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.8058 - accuracy: 0.6882 - iou_coef: 0.5362 - dice_coef: 0.5362
# Epoch 00011: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 863ms/step - loss: 4.8076 - accuracy: 0.6880 - iou_coef: 0.5361 - dice_coef: 0.5361 - val_loss: 6.9514 - val_accuracy: 0.5485 - val_iou_coef: 0.3788 - val_dice_coef: 0.3788
# Epoch 12/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7334 - accuracy: 0.6921 - iou_coef: 0.5401 - dice_coef: 0.5401
# Epoch 00012: val_accuracy did not improve from 0.55946
# 373/373 [==============================] - 322s 864ms/step - loss: 4.7348 - accuracy: 0.6920 - iou_coef: 0.5400 - dice_coef: 0.5400 - val_loss: 6.8256 - val_accuracy: 0.5534 - val_iou_coef: 0.3948 - val_dice_coef: 0.3948
# Epoch 13/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7618 - accuracy: 0.6904 - iou_coef: 0.5408 - dice_coef: 0.5408
# Epoch 00013: val_accuracy did not improve from 0.55946
#
# ...
# 373/373 [==============================] - 322s 864ms/step - loss: 4.7286 - accuracy: 0.6928 - iou_coef: 0.5364 - dice_coef: 0.5364 - val_loss: 6.7460 - val_accuracy: 0.5618 - val_iou_coef: 0.3973 - val_dice_coef: 0.3973
# Epoch 7/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.8218 - accuracy: 0.6870 - iou_coef: 0.5357 - dice_coef: 0.5357
# Epoch 00007: val_accuracy did not improve from 0.56184
# 373/373 [==============================] - 322s 863ms/step - loss: 4.8266 - accuracy: 0.6867 - iou_coef: 0.5355 - dice_coef: 0.5355 - val_loss: 7.3948 - val_accuracy: 0.5197 - val_iou_coef: 0.3722 - val_dice_coef: 0.3722
# Epoch 8/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.6828 - accuracy: 0.6957 - iou_coef: 0.5491 - dice_coef: 0.5491
# Epoch 00008: val_accuracy did not improve from 0.56184
# 373/373 [==============================] - 321s 861ms/step - loss: 4.6820 - accuracy: 0.6958 - iou_coef: 0.5489 - dice_coef: 0.5489 - val_loss: 6.7834 - val_accuracy: 0.5613 - val_iou_coef: 0.3954 - val_dice_coef: 0.3954
# Epoch 9/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.8744 - accuracy: 0.6833 - iou_coef: 0.5249 - dice_coef: 0.5249
# Epoch 00009: val_accuracy did not improve from 0.56184
# 373/373 [==============================] - 322s 863ms/step - loss: 4.8731 - accuracy: 0.6834 - iou_coef: 0.5250 - dice_coef: 0.5250 - val_loss: 7.3737 - val_accuracy: 0.5212 - val_iou_coef: 0.3781 - val_dice_coef: 0.3781
# Epoch 10/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7367 - accuracy: 0.6921 - iou_coef: 0.5447 - dice_coef: 0.5447
# Epoch 00010: val_accuracy did not improve from 0.56184
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7523 - accuracy: 0.6910 - iou_coef: 0.5430 - dice_coef: 0.5430
# Epoch 00019: val_accuracy did not improve from 0.56184
# 373/373 [==============================] - 321s 862ms/step - loss: 4.7573 - accuracy: 0.6907 - iou_coef: 0.5429 - dice_coef: 0.5429 - val_loss: 7.4239 - val_accuracy: 0.5184 - val_iou_coef: 0.3470 - val_dice_coef: 0.3470
# Epoch 20/20
# 372/373 [============================>.] - ETA: 0s - loss: 4.7520 - accuracy: 0.6912 - iou_coef: 0.5376 - dice_coef: 0.5376
# Epoch 00020: val_accuracy improved from 0.56184 to 0.56489, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-10\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 323s 865ms/step - loss: 4.7472 - accuracy: 0.6915 - iou_coef: 0.5378 - dice_coef: 0.5378 - val_loss: 6.7004 - val_accuracy: 0.5649 - val_iou_coef: 0.4313 - val_dice_coef: 0.4313
# 50/50 [==============================] - 15s 309ms/step - loss: 7.0140 - accuracy: 0.5387 - iou_coef: 0.3884 - dice_coef: 0.3884
# --- Starting trial: run-11
# {HParam(name='learning_rate', domain=Discrete([0.0001, 0.001, 0.01]), display_name=None, description=None): 0.01, HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.7, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 5}
# {'learning_rate': 0.01, 'dropout': 0.7, 'layers': 5}
# run-11 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-11
# learning rate: 0.01
# dropout: 0.7
# num layers: 5
# Epoch 1/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5155 - accuracy: 0.3124 - iou_coef: 0.3121 - dice_coef: 0.3423
# Epoch 00001: val_accuracy improved from -inf to 0.44858, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-11\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 426s 1s/step - loss: 10.5169 - accuracy: 0.3123 - iou_coef: 0.3120 - dice_coef: 0.3422 - val_loss: 8.4424 - val_accuracy: 0.4486 - val_iou_coef: 0.4494 - val_dice_coef: 0.4812
# Epoch 2/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5931 - accuracy: 0.3084 - iou_coef: 0.3091 - dice_coef: 0.3388
# Epoch 00002: val_accuracy improved from 0.44858 to 0.47796, saving model to D:PerlmutterData\logs\fit\nucleus\2020_05_15\2020_05_15_14_58\run-11\model\model_2020_05_15_14_58.h5
# 373/373 [==============================] - 426s 1s/step - loss: 10.5943 - accuracy: 0.3083 - iou_coef: 0.3091 - dice_coef: 0.3386 - val_loss: 7.9930 - val_accuracy: 0.4780 - val_iou_coef: 0.4787 - val_dice_coef: 0.5077
# Epoch 3/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5938 - accuracy: 0.3082 - iou_coef: 0.3091 - dice_coef: 0.3391
# Epoch 00003: val_accuracy did not improve from 0.47796
# 373/373 [==============================] - 421s 1s/step - loss: 10.5904 - accuracy: 0.3084 - iou_coef: 0.3093 - dice_coef: 0.3393 - val_loss: 8.2171 - val_accuracy: 0.4695 - val_iou_coef: 0.4641 - val_dice_coef: 0.4988
# Epoch 4/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5812 - accuracy: 0.3095 - iou_coef: 0.3099 - dice_coef: 0.3397
# Epoch 00004: val_accuracy did not improve from 0.47796
# 373/373 [==============================] - 421s 1s/step - loss: 10.5817 - accuracy: 0.3095 - iou_coef: 0.3099 - dice_coef: 0.3396 - val_loss: 8.2471 - val_accuracy: 0.4613 - val_iou_coef: 0.4622 - val_dice_coef: 0.4949
# Epoch 5/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5912 - accuracy: 0.3083 - iou_coef: 0.3093 - dice_coef: 0.3397
# Epoch 00005: val_accuracy did not improve from 0.47796
# 373/373 [==============================] - 421s 1s/step - loss: 10.5862 - accuracy: 0.3086 - iou_coef: 0.3096 - dice_coef: 0.3401 - val_loss: 8.2527 - val_accuracy: 0.4610 - val_iou_coef: 0.4618 - val_dice_coef: 0.4911
# Epoch 6/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.
20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5832 - accuracy: 0.3088 - iou_coef: 0.3098 - dice_coef: 0.3397
# Epoch 00014: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.5876 - accuracy: 0.3085 - iou_coef: 0.3095 - dice_coef: 0.3394 - val_loss: 8.2681 - val_accuracy: 0.4599 - val_iou_coef: 0.4608 - val_dice_coef: 0.4964
# Epoch 15/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.6246 - accuracy: 0.3056 - iou_coef: 0.3071 - dice_coef: 0.3375
# Epoch 00015: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.6142 - accuracy: 0.3063 - iou_coef: 0.3078 - dice_coef: 0.3382 - val_loss: 8.5221 - val_accuracy: 0.4434 - val_iou_coef: 0.4442 - val_dice_coef: 0.4765
# Epoch 16/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.4896 - accuracy: 0.3152 - iou_coef: 0.3159 - dice_coef: 0.3466
# Epoch 00016: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.4947 - accuracy: 0.3149 - iou_coef: 0.3156 - dice_coef: 0.3462 - val_loss: 8.2295 - val_accuracy: 0.4648 - val_iou_coef: 0.4633 - val_dice_coef: 0.4944
# Epoch 17/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5752 - accuracy: 0.3099 - iou_coef: 0.3103 - dice_coef: 0.3401
# Epoch 00017: val_accuracy did not improve from 0.49505
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 373/373 [==============================] - 421s 1s/step - loss: 10.5758 - accuracy: 0.3099 - iou_coef: 0.3103 - dice_coef: 0.3400 - val_loss: 8.2161 - val_accuracy: 0.4637 - val_iou_coef: 0.4642 - val_dice_coef: 0.4954
# Epoch 18/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.6868 - accuracy: 0.3025 - iou_coef: 0.3030 - dice_coef: 0.3332
# Epoch 00018: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.6899 - accuracy: 0.3023 - iou_coef: 0.3028 - dice_coef: 0.3330 - val_loss: 8.2214 - val_accuracy: 0.4629 - val_iou_coef: 0.4638 - val_dice_coef: 0.4997
# Epoch 19/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.5319 - accuracy: 0.3122 - iou_coef: 0.3131 - dice_coef: 0.3431
# Epoch 00019: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.5332 - accuracy: 0.3122 - iou_coef: 0.3131 - dice_coef: 0.3430 - val_loss: 8.0418 - val_accuracy: 0.4694 - val_iou_coef: 0.4755 - val_dice_coef: 0.5069
# Epoch 20/20
# 372/373 [============================>.] - ETA: 1s - loss: 10.6156 - accuracy: 0.3074 - iou_coef: 0.3077 - dice_coef: 0.3383
# Epoch 00020: val_accuracy did not improve from 0.49505
# 373/373 [==============================] - 421s 1s/step - loss: 10.6119 - accuracy: 0.3076 - iou_coef: 0.3079 - dice_coef: 0.3385 - val_loss: 8.2916 - val_accuracy: 0.4626 - val_iou_coef: 0.4593 - val_dice_coef: 0.4898
# 50/50 [==============================] - 18s 370ms/step - loss: 8.3435 - accuracy: 0.4581 - iou_coef: 0.4559 - dice_coef: 0.4878

# %%
print("Training finished")
# Out:
# Training finished

# %% [markdown]
# ## Tensorboard
# * Tensorboard for demo
# * Command: `tensorboard --logdir .\logs\fit\nucleus\2020_04_21\2020_04_21_16_21 --host 192.168.86.30 --port 6006`
# * Link: [tensorboard](http://192.168.86.30:6006/)
#
# * Tensorboard for nucleus
# * Command: `tensorboard --logdir .\logs\fit\nucleus\2020_02_06\2020_02_06_16_39 --host 192.168.86.30 --port 6006`
