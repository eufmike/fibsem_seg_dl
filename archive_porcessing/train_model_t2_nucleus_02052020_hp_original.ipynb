# %% [markdown]
# # Training Model
# 1. Keras on Tensorflow
# 2. hyper-parameter search
# 3. vanila-Unet: pull the hyper parameter setting out from the function of model
# 4. date: 01312020

# %%
import os, sys
import cv2
import numpy as np
import uuid
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
from imutils import paths
import itertools
import json
from pprint import pprint



import tensorflow as tf
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet, UNet_hp, vanilla_unet, vanilla_unet_nodrop
from core.metrics import iou_coef, dice_coef

from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorboard.plugins.hparams import api as hp
from datetime import datetime

from IPython import get_ipython
# %load_ext autoreload
get_ipython().run_line_magic('load_ext', 'autoreload')
# %autoreload 2
get_ipython().run_line_magic('autoreload', '2')
# %load_ext tensorboard
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %%
sys.executable
# Out:
# 'C:\\Users\\wucci_admin\\Anaconda3\\envs\\tfdl02\\python.exe'

# %% [markdown]
#  ## Load Training Dataset

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# input set
crop_input_set = '2020_01_23_09_51_20x'
# crop_input_set = '2020_01_30_11_24_1x' # small training set

imginput = os.path.join('dl_seg_project_raw', 'data_crop', crop_input_set,)
imgpath = os.path.join(path, imginput)

print(imgpath)

img_dir = os.path.join(imgpath, 'images')
label_dir = os.path.join(imgpath, 'labels')
print(img_dir)
print(label_dir)

# check if the output folder exist. If not, create a folder
dir_checker('logs', path)
path_logs = os.path.join(path, 'logs')
dir_checker('fit', path_logs)
dir_checker('model', path_logs)
dir_checker('pars', path_logs)
# Out:
# Load Images...
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\labels
# logs exists in D:PerlmutterData
# fit exists in D:PerlmutterData\logs
# model exists in D:PerlmutterData\logs
# pars exists in D:PerlmutterData\logs

# %% [markdown]
#  Print the first file name.

# %%
imgpath_all = list(paths.list_images(imgpath))
print(imgpath_all[0])
# Out:
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images\nucleus\0001.tif

# %% [markdown]
#  ## Create Image Datagenerator
#  1. create only one datagen
#  2. specify valiation split in datagen argument
#  3. add split data when calling `datagen.flow_from_directory`

# %%
timestamp = datetime.now().strftime("%Y_%m_%d_%H_%M")
date =  datetime.now().strftime("%Y_%m_%d")
seed = 103
batch_size = 16
epoch = 20
validation_steps = 20
validation_split = 0.1
training_sample_size = len(imgpath_all)
IMG_HEIGHT = None
IMG_WIDTH = None
classes = ['cell_membrane', 'nucleus', 'autophagosome']
inputclass = [classes[1]]
learning_rate = 1e-4
loss = "binary_crossentropy"
metrics = ['accuracy', iou_coef, dice_coef]

metrics_name = []
for f in metrics:
    if callable(f):
        metrics_name.append(f.__name__)
    else:
        metrics_name.append(f)

# %%
# create arguments for data generator
data_gen_img_args = dict(
                # featurewise_center = True,
                # featurewise_std_normalization = True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                rescale=1.0/255.0,
                )

data_gen_label_args = dict(
                # featurewise_center=True,
                # featurewise_std_normalization=True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                # rescale=1.0/255.0,
                rescale=1.0/255.0,
                )

# create parameter
pars = dict(
                # basic information
                timestamp = timestamp,
                date = date,
                seed = seed,
                batch_size = batch_size,
                
                # Data generator
                crop_input_set = crop_input_set,
                validation_steps = validation_steps,
                validation_split = validation_split,
                training_sample_size = training_sample_size,
                
                # training class
                classes = classes,
                inputclass = inputclass,
    
                # add datagen args
                data_gen_img_args = data_gen_img_args,
                data_gen_label_args = data_gen_label_args,
                
                # Build model
                IMG_HEIGHT = IMG_HEIGHT,
                IMG_WIDTH = IMG_WIDTH,
                epoch = epoch, 
                loss = loss,
                metrics_name = metrics_name,
                learning_rate = learning_rate,
                )

# save parameter
path_pars = os.path.join(path_logs, 'pars')
dir_checker(inputclass[0], path_pars)
dir_checker(date, os.path.join(path_pars, inputclass[0]))

pprint(pars)
# Out:
# nucleus exists in D:PerlmutterData\logs\pars
# 2020_02_05 exists in D:PerlmutterData\logs\pars\nucleus
# {'IMG_HEIGHT': None,
#  'IMG_WIDTH': None,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'crop_input_set': '2020_01_23_09_51_20x',
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.1,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.1,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'date': '2020_02_05',
#  'epoch': 20,
#  'inputclass': ['nucleus'],
#  'learning_rate': 0.0001,
#  'loss': 'binary_crossentropy',
#  'metrics_name': ['accuracy', 'iou_coef', 'dice_coef'],
#  'seed': 103,
#  'timestamp': '2020_02_05_16_29',
#  'training_sample_size': 13240,
#  'validation_split': 0.1,
#  'validation_steps': 20}

# %%
par_file_dir = os.path.join(path_pars, inputclass[0], date, 'pars_' + timestamp + '.json')
print(par_file_dir)

with open(par_file_dir, 'w') as outfile:
    json.dump(pars, outfile, indent=4)
# Out:
# D:PerlmutterData\logs\pars\nucleus\2020_02_05\pars_2020_02_05_16_29.json

# %%
# create generator
image_datagen = ImageDataGenerator(**data_gen_img_args)
label_datagen = ImageDataGenerator(**data_gen_label_args)

# %%
# load images into generator
train_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training', # <- define subset as 'training'
    seed=seed)

train_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training',
    seed=seed)

valid_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation', # <- define subset as 'validation'
    seed=seed)

valid_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation',
    seed=seed)
# Out:
# Found 5958 images belonging to 1 classes.
# Found 5958 images belonging to 1 classes.
# Found 662 images belonging to 1 classes.
# Found 662 images belonging to 1 classes.

# %%
# merge image and label generator
def combine_generator(gen1, gen2):
    while True:
        yield(gen1.next(), gen2.next()) 
train_generator = combine_generator(train_image_generator, train_label_generator)
valid_generator = combine_generator(valid_image_generator, valid_label_generator)

# %%
'''
train_generator = zip(train_image_generator, train_label_generator)
valid_generator = zip(valid_image_generator, valid_label_generator)
'''
# Out:
# '\ntrain_generator = zip(train_image_generator, train_label_generator)\nvalid_generator = zip(valid_image_generator, valid_label_generator)\n'

# %% [markdown]
#  ## Training

# %%
print("Start training...")
# Out:
# Start training...

# %% [markdown]
#  ### Define Callbacks

# %% [markdown]
#  ### Setup the model

# %%
# calculate steps_per_epoch
steps_per_epoch = training_sample_size * (1 - validation_split) // batch_size
print("Steps per epoch: {}".format(steps_per_epoch))
# Out:
# Steps per epoch: 744.0

# %% [markdown]
# ## Hyper-parameters grid search

# %%
# Hyperparameter
# Create a .v2 file for saving hyperparameter and evaluation
# so we can see the results on tensorboard
hparamtuning_dir = os.path.join(path_logs, 'fit', inputclass[0], date, timestamp)

HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.7, 0.5]))
HP_LAYERS = hp.HParam('layers', hp.Discrete([5, 4]))

# hparams_list = [HP_DROPOUT, HP_LAYERS]

with tf.summary.create_file_writer(hparamtuning_dir).as_default():
    hp.hparams_config(
        hparams=[HP_DROPOUT, HP_LAYERS],
        metrics=[hp.Metric('accuracy', display_name='Accuracy'), 
                 hp.Metric('iou_coef', display_name='IoU_Coef'), # create container for customized metrics
                 hp.Metric('dice_coef', display_name='Dice_Coef')], # the same
  )

# %%
def run(run_name, hparamtuning_dir, hparams):
    
    # checkpoint
    modelfilename = 'model_' + timestamp + '.h5'
    dir_checker(run_name, hparamtuning_dir)
    dir_checker('model', os.path.join(hparamtuning_dir, run_name))
    
    modelfile_path = os.path.join(hparamtuning_dir, run_name, 'model', modelfilename)
    checkpointer = ModelCheckpoint(filepath = modelfile_path, 
                                   monitor = 'val_accuracy', 
                                   mode = 'max', 
                                   verbose = 1, 
                                   save_best_only = True, 
                                  )

    # early stopping 
    early_stopping = EarlyStopping(monitor='val_loss',
                               patience=8,
                               verbose=1,
                               min_delta=1e-4)

    # learning rate adjustment
    reduceLR = ReduceLROnPlateau(monitor='val_loss',
                        factor=0.1,
                        patience=4,
                        verbose=1,
                        min_delta=1e-4)

    # tensorboard ----------------------------------------------
    
    # file_writer = create_file_writer(os.path.join(path_logs, 'fit', inputclass[0], date, timestamp, "metrics"))
    # file_writer.set_as_default()

    metrics = ['accuracy', iou_coef, dice_coef]
    
    tensorboard_callback = TensorBoard(log_dir = os.path.join(hparamtuning_dir, run_name), 
                                       profile_batch = 0, 
                                       update_freq= 30,
                                       histogram_freq = 1
                                       )

    # compile callbacks
    # callbacks = [checkpointer, tensorboard_callback, early_stopping, reduceLR]
    callbacks = [checkpointer, reduceLR, tensorboard_callback]
    
    hparamtuning_runname_dir = os.path.join(hparamtuning_dir, run_name)
    
    
    with tf.summary.create_file_writer(hparamtuning_runname_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial

        # prepare the model -----------------------------------
        
        # load hyper-parameter
        dropout = float(hparams[HP_DROPOUT])
        print('dropout: {}'.format(dropout))
        
        num_layers = int(hparams[HP_LAYERS])
        print('num layers: {}'.format(num_layers))
        
        unetmodel = vanilla_unet_nodrop(
                            shape = (IMG_HEIGHT, IMG_WIDTH), 
                            dropout = dropout, 
                            num_layers = num_layers, 
                            lr = learning_rate, 
                            loss = loss,
                            metrics = metrics,
                            summary = False,
                           )
        
        # load model ------------------------------------------
        
        '''
        # load weight
        path_model = os.path.join('D:', 'PerlmutterData', 'logs', 'model', 
                                'nucleus', 
                                '2019_12_13',
                                '2019_12_13_17_28',
                                'run-1', 
                                'model_2019_12_13_17_28.h5',)
        
        unetmodel.load_weights(path_model)
        '''
        
        
        # train the model -------------------------------------
        unetmodel.fit_generator(
                            generator = train_generator, 
                            validation_data = valid_generator,
                            validation_steps = validation_steps,
                            steps_per_epoch = steps_per_epoch,
                            epochs = epoch,  
                            callbacks = callbacks,
                            verbose = 1, 
                            )
    
        _, accuracy, iou, dice,  = unetmodel.evaluate_generator(valid_generator, steps = 50, verbose=1)
        tf.summary.scalar('accuracy', accuracy, step = 1)
        tf.summary.scalar('iou_coef', iou, step = 1)
        tf.summary.scalar('dice_coef', dice, step = 1)
        
        # -----------------------------------------------------
        
        # clean memory
        K.clear_session()
        del unetmodel

# %%
#train the model
session_num = 0

for dropout in HP_DROPOUT.domain.values:
    for layer in HP_LAYERS.domain.values:
        
        run_name = "run-{}".format(session_num)
        print('--- Starting trial: {}'.format(run_name))
        
        # create hyper-parameter
        hparams = {
            HP_DROPOUT: dropout,
            HP_LAYERS: layer,
        }
        print(hparams)
        print({h.name: hparams[h] for h in hparams})

        # build model and traning
        run(run_name, hparamtuning_dir, hparams)
        
        session_num += 1
# Out:
# --- Starting trial: run-0
# {HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.5, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 4}
# {'dropout': 0.5, 'layers': 4}
# run-0 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0
# dropout: 0.5
# num layers: 4
# Epoch 1/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.4338 - accuracy: 0.7971 - iou_coef: 0.1975 - dice_coef: 0.2548
# Epoch 00001: val_accuracy improved from -inf to 0.63900, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 647s 869ms/step - loss: 0.4339 - accuracy: 0.7970 - iou_coef: 0.1975 - dice_coef: 0.2548 - val_loss: 0.5973 - val_accuracy: 0.6390 - val_iou_coef: 0.2157 - val_dice_coef: 0.3075
# Epoch 2/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9061 - iou_coef: 0.2855 - dice_coef: 0.3270
# Epoch 00002: val_accuracy improved from 0.63900 to 0.80353, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 639s 858ms/step - loss: 0.2533 - accuracy: 0.9061 - iou_coef: 0.2856 - dice_coef: 0.3270 - val_loss: 0.5527 - val_accuracy: 0.8035 - val_iou_coef: 0.3342 - val_dice_coef: 0.3757
# Epoch 3/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9425 - iou_coef: 0.3224 - dice_coef: 0.3551
# Epoch 00003: val_accuracy did not improve from 0.80353
# 744/744 [==============================] - 636s 854ms/step - loss: 0.1846 - accuracy: 0.9426 - iou_coef: 0.3225 - dice_coef: 0.3552 - val_loss: 0.5514 - val_accuracy: 0.8021 - val_iou_coef: 0.3365 - val_dice_coef: 0.3852
# Epoch 4/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1582 - accuracy: 0.9535 - iou_coef: 0.3411 - dice_coef: 0.3698
# Epoch 00004: val_accuracy improved from 0.80353 to 0.93336, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 638s 857ms/step - loss: 0.1583 - accuracy: 0.9534 - iou_coef: 0.3410 - dice_coef: 0.3697 - val_loss: 0.1903 - val_accuracy: 0.9334 - val_iou_coef: 0.4567 - val_dice_coef: 0.4926
# Epoch 5/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1577 - accuracy: 0.9547 - iou_coef: 0.3479 - dice_coef: 0.3762
# Epoch 00005: val_accuracy improved from 0.93336 to 0.96406, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 856ms/step - loss: 0.1575 - accuracy: 0.9548 - iou_coef: 0.3477 - dice_coef: 0.3759 - val_loss: 0.1072 - val_accuracy: 0.9641 - val_iou_coef: 0.5035 - val_dice_coef: 0.5386
# Epoch 6/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9557 - iou_coef: 0.3497 - dice_coef: 0.3773
# Epoch 00006: val_accuracy improved from 0.96406 to 0.97677, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-0\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 856ms/step - loss: 0.1531 - accuracy: 0.9558 - iou_coef: 0.3498 - dice_coef: 0.3775 - val_loss: 0.0753 - val_accuracy: 0.9768 - val_iou_coef: 0.5384 - val_dice_coef: 0.5638
# Epoch 7/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9602 - iou_coef: 0.3580 - dice_coef: 0.3839
# Epoch 00007: val_accuracy did not improve from 0.97677
# 744/744 [==============================] - 635s 854ms/step - loss: 0.1415 - accuracy: 0.9601 - iou_coef: 0.3580 - dice_coef: 0.3839 - val_loss: 0.3629 - val_accuracy: 0.8805 - val_iou_coef: 0.4173 - val_dice_coef: 0.4696
# Epoch 8/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9608 - iou_coef: 0.3614 - dice_coef: 0.3870
# Epoch 00008: val_accuracy did not improve from 0.97677
# 744/744 [==============================] - 635s 854ms/step - loss: 0.1400 - accuracy: 0.9608 - iou_coef: 0.3612 - dice_coef: 0.3868 - val_loss: 0.2634 - val_accuracy: 0.9277 - val_iou_coef: 0.4393 - val_dice_coef: 0.4808
# Epoch 9/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.
20
# 743/744 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9673 - iou_coef: 0.3809 - dice_coef: 0.4009
# Epoch 00018: val_accuracy did not improve from 0.97677
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 744/744 [==============================] - 635s 853ms/step - loss: 0.0965 - accuracy: 0.9674 - iou_coef: 0.3808 - dice_coef: 0.4008 - val_loss: 0.2332 - val_accuracy: 0.9209 - val_iou_coef: 0.4462 - val_dice_coef: 0.4870
# Epoch 19/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9658 - iou_coef: 0.3817 - dice_coef: 0.4019
# Epoch 00019: val_accuracy did not improve from 0.97677
# 744/744 [==============================] - 634s 853ms/step - loss: 0.0980 - accuracy: 0.9658 - iou_coef: 0.3820 - dice_coef: 0.4022 - val_loss: 0.2513 - val_accuracy: 0.9143 - val_iou_coef: 0.4730 - val_dice_coef: 0.5198
# Epoch 20/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9677 - iou_coef: 0.3800 - dice_coef: 0.3999
# Epoch 00020: val_accuracy did not improve from 0.97677
# 744/744 [==============================] - 636s 855ms/step - loss: 0.0957 - accuracy: 0.9676 - iou_coef: 0.3799 - dice_coef: 0.3998 - val_loss: 0.1987 - val_accuracy: 0.9300 - val_iou_coef: 0.4511 - val_dice_coef: 0.4925
# 50/50 [==============================] - 17s 338ms/step - loss: 0.2292 - accuracy: 0.9211 - iou_coef: 0.4501 - dice_coef: 0.4922
# --- Starting trial: run-1
# {HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.5, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 5}
# {'dropout': 0.5, 'layers': 5}
# run-1 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-1
# dropout: 0.5
# num layers: 5
# Epoch 1/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.6284 - accuracy: 0.6879 - iou_coef: 0.1165 - dice_coef: 0.1806
# Epoch 00001: val_accuracy improved from -inf to 0.53765, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-1\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 832s 1s/step - loss: 0.6284 - accuracy: 0.6879 - iou_coef: 0.1165 - dice_coef: 0.1806 - val_loss: 0.7482 - val_accuracy: 0.5376 - val_iou_coef: 0.1392 - val_dice_coef: 0.2228
# Epoch 2/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.6231 - accuracy: 0.6904 - iou_coef: 0.1143 - dice_coef: 0.1780
# Epoch 00002: val_accuracy did not improve from 0.53765
# 744/744 [==============================] - 824s 1s/step - loss: 0.6232 - accuracy: 0.6901 - iou_coef: 0.1145 - dice_coef: 0.1781 - val_loss: 0.7916 - val_accuracy: 0.5302 - val_iou_coef: 0.1710 - val_dice_coef: 0.2634
# Epoch 3/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5973 - accuracy: 0.6895 - iou_coef: 0.1231 - dice_coef: 0.1880
# Epoch 00003: val_accuracy did not improve from 0.53765
# 744/744 [==============================] - 824s 1s/step - loss: 0.5973 - accuracy: 0.6896 - iou_coef: 0.1231 - dice_coef: 0.1880 - val_loss: 0.8057 - val_accuracy: 0.5356 - val_iou_coef: 0.1507 - val_dice_coef: 0.2273
# Epoch 4/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5370 - accuracy: 0.7027 - iou_coef: 0.1438 - dice_coef: 0.2094
# Epoch 00004: val_accuracy improved from 0.53765 to 0.68592, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-1\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 831s 1s/step - loss: 0.5368 - accuracy: 0.7029 - iou_coef: 0.1438 - dice_coef: 0.2094 - val_loss: 0.9173 - val_accuracy: 0.6859 - val_iou_coef: 0.1682 - val_dice_coef: 0.2323
# Epoch 5/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5192 - accuracy: 0.7276 - iou_coef: 0.1480 - dice_coef: 0.2115
# Epoch 00005: val_accuracy improved from 0.68592 to 0.69987, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-1\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] -
ARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 743/744 [============================>.] - ETA: 0s - loss: 0.6022 - accuracy: 0.6924 - iou_coef: 0.1223 - dice_coef: 0.1866
# Epoch 00001: val_accuracy improved from -inf to 0.52221, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 638s 858ms/step - loss: 0.6022 - accuracy: 0.6924 - iou_coef: 0.1222 - dice_coef: 0.1866 - val_loss: 0.7596 - val_accuracy: 0.5222 - val_iou_coef: 0.1453 - val_dice_coef: 0.2322
# Epoch 2/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.5559 - accuracy: 0.6921 - iou_coef: 0.1380 - dice_coef: 0.2042
# Epoch 00002: val_accuracy improved from 0.52221 to 0.57119, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 638s 857ms/step - loss: 0.5559 - accuracy: 0.6923 - iou_coef: 0.1379 - dice_coef: 0.2040 - val_loss: 0.9447 - val_accuracy: 0.5712 - val_iou_coef: 0.1229 - val_dice_coef: 0.1873
# Epoch 3/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.4985 - accuracy: 0.7527 - iou_coef: 0.1666 - dice_coef: 0.2295
# Epoch 00003: val_accuracy improved from 0.57119 to 0.69980, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 638s 858ms/step - loss: 0.4983 - accuracy: 0.7528 - iou_coef: 0.1667 - dice_coef: 0.2295 - val_loss: 0.9919 - val_accuracy: 0.6998 - val_iou_coef: 0.2029 - val_dice_coef: 0.2566
# Epoch 4/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.2796 - accuracy: 0.8955 - iou_coef: 0.2723 - dice_coef: 0.3160
# Epoch 00004: val_accuracy improved from 0.69980 to 0.75900, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 856ms/step - loss: 0.2794 - accuracy: 0.8956 - iou_coef: 0.2721 - dice_coef: 0.3158 - val_loss: 0.7782 - val_accuracy: 0.7590 - val_iou_coef: 0.2083 - val_dice_coef: 0.2463
# Epoch 5/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1929 - accuracy: 0.9375 - iou_coef: 0.3227 - dice_coef: 0.3565
# Epoch 00005: val_accuracy improved from 0.75900 to 0.80456, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 857ms/step - loss: 0.1927 - accuracy: 0.9375 - iou_coef: 0.3226 - dice_coef: 0.3564 - val_loss: 0.5453 - val_accuracy: 0.8046 - val_iou_coef: 0.3143 - val_dice_coef: 0.3585
# Epoch 6/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9531 - iou_coef: 0.3435 - dice_coef: 0.3726
# Epoch 00006: val_accuracy did not improve from 0.80456
# 744/744 [==============================] - 635s 854ms/step - loss: 0.1580 - accuracy: 0.9530 - iou_coef: 0.3437 - dice_coef: 0.3728 - val_loss: 0.5892 - val_accuracy: 0.7942 - val_iou_coef: 0.3882 - val_dice_coef: 0.4343
# Epoch 7/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9569 - iou_coef: 0.3500 - dice_coef: 0.3773
# Epoch 00007: val_accuracy improved from 0.80456 to 0.85341, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 857ms/step - loss: 0.1465 - accuracy: 0.9569 - iou_coef: 0.3501 - dice_coef: 0.3774 - val_loss: 0.4432 - val_accuracy: 0.8534 - val_iou_coef: 0.3497 - val_dice_coef: 0.3934
# Epoch 8/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9485 - iou_coef: 0.3433 - dice_coef: 0.3727
# Epoch 00008: val_accuracy improved from 0.85341 to 0.85639, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 636s 855ms/step - loss: 0.1656 - accuracy: 0.9485 - iou_coef: 0.3433 - dice_coef: 0.3727 - val_loss: 0.4249 - val_accuracy: 0.8564 - val_iou_coef: 0.3712 - val_dice_coef: 0.4194
# Epoch 9/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1439 - accuracy: 0.9596 - iou_coef: 0.3543 - dice_coef: 0.3802
# Epoch 00009: val_accuracy did not improve from 0.85639
# 744/744 [==============================] - 635s 853ms/step - loss: 0.1438 - accuracy: 0.9596 - iou_coef: 0.3540 - dice_coef: 0.3799 - val_loss: 0.7439 - val_accuracy: 0.7886 - val_iou_coef: 0.3091 - val_dice_coef: 0.3459
# Epoch 10/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1377 - accuracy: 0.9612 - iou_coef: 0.3610 - dice_coef: 0.3864
# Epoch 00010: val_accuracy did not improve from 0.85639
# 744/744 [==============================] - 634s 852ms/step - loss: 0.1379 - accuracy: 0.9611 - iou_coef: 0.3608 - dice_coef: 0.3862 - val_loss: 0.5352 - val_accuracy: 0.8203 - val_iou_coef: 0.3514 - val_dice_coef: 0.3912
# Epoch 11/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1399 - accuracy: 0.9606 - iou_coef: 0.3586 - dice_coef: 0.3845
# Epoch 00011: val_accuracy improved from 0.85639 to 0.86931, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 636s 854ms/step - loss: 0.1398 - accuracy: 0.9607 - iou_coef: 0.3587 - dice_coef: 0.3846 - val_loss: 0.4000 - val_accuracy: 0.8693 - val_iou_coef: 0.4043 - val_dice_coef: 0.4465
# Epoch 12/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9615 - iou_coef: 0.3619 - dice_coef: 0.3871
# Epoch 00012: val_accuracy improved from 0.86931 to 0.90899, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 635s 854ms/step - loss: 0.1370 - accuracy: 0.9616 - iou_coef: 0.3618 - dice_coef: 0.3870 - val_loss: 0.2472 - val_accuracy: 0.9090 - val_iou_coef: 0.4011 - val_dice_coef: 0.4490
# Epoch 13/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9642 - iou_coef: 0.3680 - dice_coef: 0.3922
# Epoch 00013: val_accuracy did not improve from 0.90899
# 744/744 [==============================] - 633s 851ms/step - loss: 0.1278 - accuracy: 0.9642 - iou_coef: 0.3679 - dice_coef: 0.3921 - val_loss: 0.8685 - val_accuracy: 0.8002 - val_iou_coef: 0.3120 - val_dice_coef: 0.3470
# Epoch 14/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1367 - accuracy: 0.9614 - iou_coef: 0.3642 - dice_coef: 0.3893
# Epoch 00014: val_accuracy improved from 0.90899 to 0.95826, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 637s 856ms/step - loss: 0.1366 - accuracy: 0.9614 - iou_coef: 0.3642 - dice_coef: 0.3893 - val_loss: 0.1328 - val_accuracy: 0.9583 - val_iou_coef: 0.4900 - val_dice_coef: 0.5196
# Epoch 15/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9625 - iou_coef: 0.3654 - dice_coef: 0.3897
# Epoch 00015: val_accuracy did not improve from 0.95826
# 744/744 [==============================] - 634s 852ms/step - loss: 0.1324 - accuracy: 0.9626 - iou_coef: 0.3655 - dice_coef: 0.3898 - val_loss: 0.2040 - val_accuracy: 0.9256 - val_iou_coef: 0.4745 - val_dice_coef: 0.5197
# Epoch 16/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1270 - accuracy: 0.9641 - iou_coef: 0.3712 - dice_coef: 0.3950
# Epoch 00016: val_accuracy did not improve from 0.95826
# 744/744 [==============================] - 633s 851ms/step - loss: 0.1273 - accuracy: 0.9640 - iou_coef: 0.3715 - dice_coef: 0.3953 - val_loss: 0.3112 - val_accuracy: 0.8904 - val_iou_coef: 0.4288 - val_dice_coef: 0.4771
# Epoch 17/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1204 - accuracy: 0.9653 - iou_coef: 0.3688 - dice_coef: 0.3918
# Epoch 00017: val_accuracy improved from 0.95826 to 0.98026, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 636s 854ms/step - loss: 0.1203 - accuracy: 0.9653 - iou_coef: 0.3686 - dice_coef: 0.3916 - val_loss: 0.0759 - val_accuracy: 0.9803 - val_iou_coef: 0.4954 - val_dice_coef: 0.5265
# Epoch 18/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1197 - accuracy: 0.9646 - iou_coef: 0.3714 - dice_coef: 0.3944
# Epoch 00018: val_accuracy did not improve from 0.98026
# 744/744 [==============================] - 634s 852ms/step - loss: 0.1198 - accuracy: 0.9646 - iou_coef: 0.3713 - dice_coef: 0.3942 - val_loss: 0.1567 - val_accuracy: 0.9451 - val_iou_coef: 0.4576 - val_dice_coef: 0.5044
# Epoch 19/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9649 - iou_coef: 0.3769 - dice_coef: 0.3996
# Epoch 00019: val_accuracy improved from 0.98026 to 0.98182, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-2\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 636s 854ms/step - loss: 0.1172 - accuracy: 0.9648 - iou_coef: 0.3770 - dice_coef: 0.3998 - val_loss: 0.0704 - val_accuracy: 0.9818 - val_iou_coef: 0.5376 - val_dice_coef: 0.5624
# Epoch 20/20
# 743/744 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9655 - iou_coef: 0.3754 - dice_coef: 0.3980
# Epoch 00020: val_accuracy did not improve from 0.98182
# 744/744 [==============================] - 633s 850ms/step - loss: 0.1134 - accuracy: 0.9655 - iou_coef: 0.3755 - dice_coef: 0.3980 - val_loss: 0.1493 - val_accuracy: 0.9630 - val_iou_coef: 0.4418 - val_dice_coef: 0.4930
# 50/50 [==============================] - 16s 311ms/step - loss: 0.1483 - accuracy: 0.9624 - iou_coef: 0.4516 - dice_coef: 0.5002
# --- Starting trial: run-3
# {HParam(name='dropout', domain=Discrete([0.5, 0.7]), display_name=None, description=None): 0.7, HParam(name='layers', domain=Discrete([4, 5]), display_name=None, description=None): 5}
# {'dropout': 0.7, 'layers': 5}
# run-3 does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29
# model does not exist in D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3
# dropout: 0.7
# num layers: 5
# Epoch 1/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5868 - accuracy: 0.6980 - iou_coef: 0.1283 - dice_coef: 0.1923
# Epoch 00001: val_accuracy improved from -inf to 0.53787, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 833s 1s/step - loss: 0.5869 - accuracy: 0.6979 - iou_coef: 0.1284 - dice_coef: 0.1925 - val_loss: 0.8424 - val_accuracy: 0.5379 - val_iou_coef: 0.1672 - val_dice_coef: 0.2436
# Epoch 2/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5390 - accuracy: 0.7049 - iou_coef: 0.1453 - dice_coef: 0.2101
# Epoch 00002: val_accuracy did not improve from 0.53787
# 744/744 [==============================] - 826s 1s/step - loss: 0.5389 - accuracy: 0.7050 - iou_coef: 0.1453 - dice_coef: 0.2100 - val_loss: 1.2765 - val_accuracy: 0.5191 - val_iou_coef: 0.1333 - val_dice_coef: 0.1932
# Epoch 3/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5369 - accuracy: 0.7285 - iou_coef: 0.1492 - dice_coef: 0.2123
# Epoch 00003: val_accuracy improved from 0.53787 to 0.55593, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 828s 1s/step - loss: 0.5369 - accuracy: 0.7284 - iou_coef: 0.1492 - dice_coef: 0.2123 - val_loss: 0.8393 - val_accuracy: 0.5559 - val_iou_coef: 0.1284 - val_dice_coef: 0.1969
# Epoch 4/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.5217 - accuracy: 0.7134 - iou_coef: 0.1498 - dice_coef: 0.2146
# Epoch 00004: val_accuracy did not improve from 0.55593
# 744/744 [==============================] - 822s 1s/step - loss: 0.5219 - accuracy: 0.7132 - iou_coef: 0.1499 - dice_coef: 0.2147 - val_loss: 0.9595 - val_accuracy: 0.5488 - val_iou_coef: 0.1026 - val_dice_coef: 0.1662
# Epoch 5/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.4481 - accuracy: 0.7765 - iou_coef: 0.1834 - dice_coef: 0.2406
# Epoch 00005: val_accuracy improved from 0.55593 to 0.76918, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 829s 1s/step - loss: 0.4475 - accuracy: 0.7768 - iou_coef: 0.1838 - dice_coef: 0.2410 - val_loss: 0.8195 - val_accuracy: 0.7692 - val_iou_coef: 0.2581 - val_dice_coef: 0.2844
# Epoch 6/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1901 - accuracy: 0.9416 - iou_coef: 0.3163 - dice_coef: 0.3466
# Epoch 00006: val_accuracy improved from 0.76918 to 0.80408, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 831s 1s/step - loss: 0.1899 - accuracy: 0.9417 - iou_coef: 0.3165 - dice_coef: 0.3468 - val_loss: 0.7497 - val_accuracy: 0.8041 - val_iou_coef: 0.2840 - val_dice_coef: 0.3082
# Epoch 7/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1571 - accuracy: 0.9557 - iou_coef: 0.3402 - dice_coef: 0.3666
# Epoch 00007: val_accuracy did not improve from 0.80408
# 744/744 [==============================] - 825s 1s/step - loss: 0.1570 - accuracy: 0.9557 - iou_coef: 0.3400 - dice_coef: 0.3664 - val_loss: 0.9537 - val_accuracy: 0.7806 - val_iou_coef: 0.3025 - val_dice_coef: 0.3244
# Epoch 8/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1501 - accuracy: 0.9572 - iou_coef: 0.3485 - dice_coef: 0.3743
# Epoch 00008: val_accuracy improved from 0.80408 to 0.83519, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 830s 1s/step - loss: 0.1501 - accuracy: 0.9573 - iou_coef: 0.3485 - dice_coef: 0.3743 - val_loss: 0.5217 - val_accuracy: 0.8352 - val_iou_coef: 0.3217 - val_dice_coef: 0.3500
# Epoch 9/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1375 - accuracy: 0.9622 - iou_coef: 0.3568 - dice_coef: 0.3807
# Epoch 00009: val_accuracy did not improve from 0.83519
# 744/744 [==============================] - 823s 1s/step - loss: 0.1374 - accuracy: 0.9622 - iou_coef: 0.3568 - dice_coef: 0.3807 - val_loss: 0.6385 - val_accuracy: 0.8273 - val_iou_coef: 0.3133 - val_dice_coef: 0.3407
# Epoch 10/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1476 - accuracy: 0.9588 - iou_coef: 0.3509 - dice_coef: 0.3755
# Epoch 00010: val_accuracy improved from 0.83519 to 0.97615, saving model to D:PerlmutterData\logs\fit\nucleus\2020_02_05\2020_02_05_16_29\run-3\model\model_2020_02_05_16_29.h5
# 744/744 [==============================] - 828s 1s/step - loss: 0.1478 - accuracy: 0.9588 - iou_coef: 0.3509 - dice_coef: 0.3755 - val_loss: 0.0897 - val_accuracy: 0.9762 - val_iou_coef: 0.4779 - val_dice_coef: 0.4992
# Epoch 11/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1384 - accuracy: 0.9618 - iou_coef: 0.3590 - dice_coef: 0.3829
# Epoch 00011: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 825s 1s/step - loss: 0.1383 - accuracy: 0.9619 - iou_coef: 0.3592 - dice_coef: 0.3830 - val_loss: 0.4077 - val_accuracy: 0.8863 - val_iou_coef: 0.4032 - val_dice_coef: 0.4405
# Epoch 12/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1390 - accuracy: 0.9621 - iou_coef: 0.3610 - dice_coef: 0.3847
# Epoch 00012: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 825s 1s/step - loss: 0.1390 - accuracy: 0.9621 - iou_coef: 0.3608 - dice_coef: 0.3845 - val_loss: 0.8813 - val_accuracy: 0.7771 - val_iou_coef: 0.2504 - val_dice_coef: 0.2755
# Epoch 13/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1296 - accuracy: 0.9651 - iou_coef: 0.3645 - dice_coef: 0.3877
# Epoch 00013: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 824s 1s/step - loss: 0.1295 - accuracy: 0.9651 - iou_coef: 0.3643 - dice_coef: 0.3876 - val_loss: 0.4320 - val_accuracy: 0.8715 - val_iou_coef: 0.3754 - val_dice_coef: 0.4144
# Epoch 14/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1841 - accuracy: 0.9362 - iou_coef: 0.3378 - dice_coef: 0.3660
# Epoch 00014: val_accuracy did not improve from 0.97615
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 744/744 [==============================] - 824s 1s/step - loss: 0.1844 - accuracy: 0.9361 - iou_coef: 0.3377 - dice_coef: 0.3660 - val_loss: 0.1678 - val_accuracy: 0.9485 - val_iou_coef: 0.4626 - val_dice_coef: 0.4957
# Epoch 15/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1254 - accuracy: 0.9662 - iou_coef: 0.3633 - dice_coef: 0.3863
# Epoch 00015: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 823s 1s/step - loss: 0.1253 - accuracy: 0.9662 - iou_coef: 0.3633 - dice_coef: 0.3862 - val_loss: 0.5990 - val_accuracy: 0.8314 - val_iou_coef: 0.3852 - val_dice_coef: 0.4172
# Epoch 16/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1221 - accuracy: 0.9670 - iou_coef: 0.3703 - dice_coef: 0.3923
# Epoch 00016: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 823s 1s/step - loss: 0.1220 - accuracy: 0.9671 - iou_coef: 0.3703 - dice_coef: 0.3923 - val_loss: 0.4285 - val_accuracy: 0.8802 - val_iou_coef: 0.3968 - val_dice_coef: 0.4307
# Epoch 17/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1189 - accuracy: 0.9669 - iou_coef: 0.3691 - dice_coef: 0.3909
# Epoch 00017: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 823s 1s/step - loss: 0.1188 - accuracy: 0.9669 - iou_coef: 0.3690 - dice_coef: 0.3908 - val_loss: 0.6193 - val_accuracy: 0.8391 - val_iou_coef: 0.3482 - val_dice_coef: 0.3743
# Epoch 18/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1165 - accuracy: 0.9674 - iou_coef: 0.3760 - dice_coef: 0.3984
# Epoch 00018: val_accuracy did not improve from 0.97615
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 744/744 [==============================] - 823s 1s/step - loss: 0.1165 - accuracy: 0.9675 - iou_coef: 0.3759 - dice_coef: 0.3983 - val_loss: 0.3808 - val_accuracy: 0.8837 - val_iou_coef: 0.4085 - val_dice_coef: 0.4392
# Epoch 19/20
# 743/744 [============================>.] - ETA: 1s - loss: 0.1129 - accuracy: 0.9679 - iou_coef: 0.3725 - dice_coef: 0.3932
# Epoch 00019: val_accuracy did not improve from 0.97615
# 744/744 [==============================] - 823s 1s/step - loss: 0.1128 - accuracy: 0.9679 - iou_coef: 0.3728 - dice_coef: 0.3936 - val_loss: 0.5339 - val_accuracy: 0.8500 - val_iou_coef: 0.3498 - val_dice_coef: 0.3782
# Epoch 20/20
# 317/744 [===========>..................] - ETA: 7:40 - loss: 0.1075 - accuracy: 0.9693 - iou_coef: 0.3742 - dice_coef: 0.3943

# %%
print("Training finished")
