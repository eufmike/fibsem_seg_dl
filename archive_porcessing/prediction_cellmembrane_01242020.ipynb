# %% [markdown]
#  # Prediction
#  Keras on Tensorflow
#
#  This prediction runs on all 9 dataset.

# %%
import os, sys
import cv2
import numpy as np
import uuid
import tensorflow as tf
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
from imutils import paths
import itertools
import json
from pprint import pprint

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet
from core.metrics import iou_coef, dice_coef


from tensorflow.keras.models import load_model
from datetime import datetime

from core.imageprep import create_crop_idx, crop_to_patch, construct_from_patch, create_crop_idx_whole
from core.train_predict import stack_predict, stack_predict_v2
from tqdm.notebook import trange

from IPython import get_ipython
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %% [markdown]
#  ## Load Training Dataset

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# experiment
exp_name = 'dl_seg_project_raw'

# label
label = 'cell_membrane'

# trianing timestamp
training_date = '2019_12_06'
imginput_timestamp = '2019_12_06_17_06'
# model_training_timestamp = '2019_12_11_12_21'
model_training_timestamp = '2019_12_06_17_14'
print('Training timestamp: {}'.format(model_training_timestamp))

# input img path
imginput = os.path.join(exp_name, 'data_crop', imginput_timestamp)
imgpath = os.path.join(path, imginput)
print('Input Images Path: {}'.format(imgpath))

# model path
modelfd = 'model'
modelfn = 'model_' + model_training_timestamp + '.h5'
path_model = os.path.join(path, 'logs', modelfd, label, training_date, modelfn)
print('Model Path: {}'.format(path_model))

# raw path
rawfd = 'raw_input_image'
path_raw = os.path.join(path, rawfd)
print('Raw Path: {}'.format(path_raw))

# prediction path
pred_path = os.path.join(path, exp_name)
dir_checker('pred_img', pred_path)
# Out:
# Load Images...
# Training timestamp: 2019_12_06_17_14
# Input Images Path: D:PerlmutterData\dl_seg_project_raw\data_crop\2019_12_06_17_06
# Model Path: D:PerlmutterData\logs\model\cell_membrane\2019_12_06\model_2019_12_06_17_14.h5
# Raw Path: D:PerlmutterData\raw_input_image
# pred_img exists in D:PerlmutterData\dl_seg_project_raw

# %% [markdown]
# ## Parameter

# %%
# load parameter
parsfd = 'pars'
parsfn = 'pars_' + model_training_timestamp + '.json'
path_pars = os.path.join(path, 'logs', parsfd, label, training_date, parsfn)

with open(path_pars) as json_file:
    pars = json.load(json_file)

# %%
pprint(pars)
# Out:
# {'IMG_HEIGHT': 256,
#  'IMG_WIDTH': 256,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.1,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.1,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'epoch': 500,
#  'inputclass': ['cell_membrane'],
#  'learning_rate': 1e-05,
#  'loss': 'binary_crossentropy',
#  'metrics': ['accuracy'],
#  'seed': 100,
#  'timestamp': '2019_12_06_17_14',
#  'training_sample_size': 54100,
#  'validation_split': 0.1,
#  'validation_steps': 20}

# %%
label = pars['inputclass']
IMG_HEIGHT = pars['IMG_HEIGHT']
IMG_WIDTH = pars['IMG_WIDTH']

IMG_HEIGHT = 256
IMG_WIDTH = 256

# %% [markdown]
# ## Predict from Testing Dataset

# %%
# get dataset
rawfdlist = os.listdir(path_raw)
rawfdlist = rawfdlist[:3]
# rawfdlist = list(rawfdlist[i] for i in [1])
print(rawfdlist)
# Out:
# ['data_d00_batch01_loc01', 'data_d00_batch02_loc02', 'data_d00_batch02_loc03']

# %%
rawimglist = {}
for folder in rawfdlist:
    print(folder)
    rawimglist[folder] = list(paths.list_images(os.path.join(path_raw, folder, 'image')))
# Out:
# data_d00_batch01_loc01
# data_d00_batch02_loc02
# data_d00_batch02_loc03

# %%
pprint(rawimglist)
# Out:
# {'data_d00_batch01_loc01': ['D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0001.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0002.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0003.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0004.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0005.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0006.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0007.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0008.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0009.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0010.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0011.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0012.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0013.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0014.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0015.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0016.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0017.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0018.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0019.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0020.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0021.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0022.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0023.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0024.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0025.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0026.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0027.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0028.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0029.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0030.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0031.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0032.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0033.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0034.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0035.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0036.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0037.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0038.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0039.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0040.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0041.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0042.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0043.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0044.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0045.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0046.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0047.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0048.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0049.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0050.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0051.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0052.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0053.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0054.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0055.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0056.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0057.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0058.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0059.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0060.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0061.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0062.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0063.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0064.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0065.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0066.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0067.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0068.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0069.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0070.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0071.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0072.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0073.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0074.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0075.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0076.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0077.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0078.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0079.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0080.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0081.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0082.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0083.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0084.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0085.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0086.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0087.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0088.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0089.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0090.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0091.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0092.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0093.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0094.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0095.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0096.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0097.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0098.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0099.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0100.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0101.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0102.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0103.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0104.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0105.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0106.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0107.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0108.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0109.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0110.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0111.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0112.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0113.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0114.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0115.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0116.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0117.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0118.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0119.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0120.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0121.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0122.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0123.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0124.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0125.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0126.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0127.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0128.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0129.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0130.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0131.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0132.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0133.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0134.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0135.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0136.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0137.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0138.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0139.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0140.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0141.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0142.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0143.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0144.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0145.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0146.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0147.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0148.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0149.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0150.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0151.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0152.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0153.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0154.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0155.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0156.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0157.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0158.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0159.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0160.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0161.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0162.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0163.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0164.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0165.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0166.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0167.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0168.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0169.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0170.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0171.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0172.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0173.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0174.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0175.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0176.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0177.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0178.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0179.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0180.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0181.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0182.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0183.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0184.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0185.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0186.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0187.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0188.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0189.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0190.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0191.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0192.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0193.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0194.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0195.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0196.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0197.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0198.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0199.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0200.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0201.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0202.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0203.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0204.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0205.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0206.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0207.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0208.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0209.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0210.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0211.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0212.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0213.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0214.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0215.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0216.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0217.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0218.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0219.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0220.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0221.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0222.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0223.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0224.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0225.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0226.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0227.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0228.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0229.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0230.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0231.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0232.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0233.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0234.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0235.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0236.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0237.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0238.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0239.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0240.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0241.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0242.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0243.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0244.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0245.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0246.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0247.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0248.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0249.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0250.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0251.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0252.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0253.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0254.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0255.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0256.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0257.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0258.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0259.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0260.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0261.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0262.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0263.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0264.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0265.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0266.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0267.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0268.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0269.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0270.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0271.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0272.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0273.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0274.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0275.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0276.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0277.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0278.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0279.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0280.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0281.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0282.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0283.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0284.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0285.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0286.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0287.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0288.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0289.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0290.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0291.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0292.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0293.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0294.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0295.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0296.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0297.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0298.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0299.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0300.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0301.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0302.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0303.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0304.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0305.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0306.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0307.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0308.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0309.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0310.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0311.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0312.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0313.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0314.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0315.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0316.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0317.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0318.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0319.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0320.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0321.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0322.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0323.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0324.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0325.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0326.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0327.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0328.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0329.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0330.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0331.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0332.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0333.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0334.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0335.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0336.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0337.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0338.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0339.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0340.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0341.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0342.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0343.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0344.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0345.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0346.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0347.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0348.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0349.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0350.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0351.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0352.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0353.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0354.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0355.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0356.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0357.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0358.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0359.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0360.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0361.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0362.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0363.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0364.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0365.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0366.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0367.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0368.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0369.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0370.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0371.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0372.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0373.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0374.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0375.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0376.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch01_loc01\\image\\TH-4891-0dayDOX-B-M3_0377.tif',
# ...
#                             '0day DOX D A12 2nd time_1141.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1142.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1143.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1144.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1145.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1146.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1147.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1148.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1149.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1150.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1151.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1152.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1153.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1154.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1155.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1156.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1157.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1158.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1159.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1160.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1161.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1162.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1163.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1164.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1165.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1166.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1167.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1168.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1169.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1170.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1171.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1172.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1173.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1174.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1175.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1176.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1177.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1178.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1179.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1180.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1181.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1182.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1183.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1184.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1185.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1186.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1187.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1188.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1189.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1190.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1191.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1192.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1193.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1194.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1195.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1196.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1197.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1198.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1199.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1200.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1201.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1202.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1203.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1204.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1205.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1206.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1207.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1208.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1209.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1210.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1211.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1212.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1213.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1214.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1215.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1216.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1217.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1218.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1219.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1220.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1221.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1222.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1223.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1224.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1225.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1226.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1227.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1228.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1229.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1230.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1231.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1232.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1233.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1234.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc03\\image\\TH-4891 '
#                             '0day DOX D A12 2nd time_1235.tif']}

# %% [markdown]
# ## Define Prediction Set

# %%
samplesize = 10
rawimglist_small = {}
for idx, item in rawimglist.items():
    rawimglist_small[idx] = rawimglist[idx][:samplesize]
# pprint(rawimglist_small)

# %%
img = imread(rawimglist[rawfdlist[0]][0])
plt.figure(figsize = (20,20))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
'''
model = load_model(path_model, custom_objects={'iou_coef': iou_coef, 'dice_coef': dice_coef})
print(model)
'''
# Out:
# "\nmodel = load_model(path_model, custom_objects={'iou_coef': iou_coef, 'dice_coef': dice_coef})\nprint(model)\n"

# %%
img_tmp = img * 1./255.
print(img_tmp.shape)
# Out:
# (883, 2297)

# %%
learning_rate = 1e-5
loss = "binary_crossentropy"
metrics = ['accuracy', iou_coef, dice_coef]

model = UNet(shape = (None, None), 
             lr = learning_rate, 
             loss = loss,
             metrics = metrics,)

model.load_weights(path_model)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 1 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 5 1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 5 2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 5 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, None, None, 1 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 5 2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 5 4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 5 2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 5 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 2 524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 2 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 1 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, None, None, 1 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
label = pars['inputclass'][0]
opdir = os.path.join(pred_path, 'pred_img')
fdnm_small = 'batch_small_fullsize'

def checkpredfolder(rawfdlist, opdir, opfolder, label):
    # folder name
    dir_checker(label, opdir)
    img_path_small = os.path.join(opdir, label)
    dir_checker(opfolder, img_path_small)

    # create folder list
    for folder in rawfdlist:
        dir_checker(folder, os.path.join(img_path_small, opfolder))

checkpredfolder(rawfdlist, opdir, fdnm_small, label)
# Out:
# cell_membrane exists in D:PerlmutterData\dl_seg_project_raw\pred_img
# batch_small_fullsize exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane
# data_d00_batch01_loc01 does not exist in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_small_fullsize
# data_d00_batch02_loc02 exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_small_fullsize
# data_d00_batch02_loc03 does not exist in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_small_fullsize

# %%
from core.imageprep import create_crop_idx, crop_to_patch
from core.train_predict import stack_predict_v2

for idx in trange(len(rawfdlist)):
    
    folder = rawfdlist[idx]
    
    pred_input_imgs =  rawimglist_small[folder]
    pred_output_path = os.path.join(opdir, label, fdnm_small, folder)
    
    img = imread(rawimglist_small[folder][0])
    cropidx = create_crop_idx_whole(img.shape, (IMG_HEIGHT, IMG_WIDTH), overlap_fac = 0.1)
    print(cropidx)
    
    stack_predict_v2(
                input_imgpath = pred_input_imgs, 
                output_imgpath = pred_output_path, 
                cropidx = cropidx, 
                model = model, 
                rescale = 1./255.,
                patch_size = (IMG_HEIGHT, IMG_WIDTH), 
                predict_threshold = 0.5)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# [[   0  256 2041 2297    0    9]
#  [ 230  486 2041 2297    1    9]
#  [ 460  716 2041 2297    2    9]
#  [ 627  883    0  256    3    0]
#  [ 627  883  230  486    3    1]
#  [ 627  883  460  716    3    2]
#  [ 627  883  690  946    3    3]
#  [ 627  883  920 1176    3    4]
#  [ 627  883 1150 1406    3    5]
#  [ 627  883 1380 1636    3    6]
#  [ 627  883 1610 1866    3    7]
#  [ 627  883 1840 2096    3    8]
#  [ 627  883 2041 2297    3    9]]
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# C:\Users\wucci_admin\Documents\code\dl_fibem_seg\core\imageprep.py:554: RuntimeWarning: Mean of empty slice
#   outputimg = np.nanmean(img_stack_repos, axis = 0)
# C:\Users\wucci_admin\Anaconda3\envs\tfdl02\lib\site-packages\skimage\external\tifffile\tifffile.py:2618: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# [[   0  256 1523 1779    0    7]
#  [ 230  486 1523 1779    1    7]
#  [ 449  705    0  256    2    0]
#  [ 449  705  230  486    2    1]
#  [ 449  705  460  716    2    2]
#  [ 449  705  690  946    2    3]
#  [ 449  705  920 1176    2    4]
#  [ 449  705 1150 1406    2    5]
#  [ 449  705 1380 1636    2    6]
#  [ 449  705 1523 1779    2    7]]
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# [[   0  256 1654 1910    0    8]
#  [ 230  486 1654 1910    1    8]
#  [ 255  511    0  256    2    0]
#  [ 255  511  230  486    2    1]
#  [ 255  511  460  716    2    2]
#  [ 255  511  690  946    2    3]
#  [ 255  511  920 1176    2    4]
#  [ 255  511 1150 1406    2    5]
#  [ 255  511 1380 1636    2    6]
#  [ 255  511 1610 1866    2    7]
#  [ 255  511 1654 1910    2    8]]
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %% [markdown]
# ## Prediction Small Dataset with tiles
# ### Create Folder

# %% [markdown]
# ## Prediction Small Dataset with tiles (whole stack)
# ### Create Folder

# %%
# folder name
fdnm_total = 'batch_total_fullsize'
checkpredfolder(rawfdlist, opdir, fdnm_total, label)
# Out:
# cell_membrane exists in D:PerlmutterData\dl_seg_project_raw\pred_img
# batch_total_fullsize exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane
# data_d00_batch01_loc01 does not exist in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_total_fullsize
# data_d00_batch02_loc02 exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_total_fullsize
# data_d00_batch02_loc03 does not exist in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_total_fullsize

# %% [markdown]
# ### Tiling Prediction with Stack Input
# - Crop image into patched by a given overlap factor
# - Export a cropping index
# - Construct patches back into a image

# %%
from core.imageprep import create_crop_idx, crop_to_patch
from core.train_predict import stack_predict_v2

for idx in trange(len(rawfdlist)):
    
    folder = rawfdlist[idx]
    
    pred_input_imgs =  rawimglist[folder]
    pred_output_path = os.path.join(opdir, label, fdnm_total, folder)
    
    img = imread(rawimglist_small[folder][0])
    cropidx = create_crop_idx_whole(img.shape, (IMG_HEIGHT, IMG_WIDTH), overlap_fac = 0.1)
    print(cropidx)
    
    stack_predict_v2(
                input_imgpath = pred_input_imgs, 
                output_imgpath = pred_output_path, 
                cropidx = cropidx, 
                model = model, 
                rescale = 1./255.,
                patch_size = (IMG_HEIGHT, IMG_WIDTH), 
                predict_threshold = 0.5)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# [[   0  256 2041 2297    0    9]
#  [ 230  486 2041 2297    1    9]
#  [ 460  716 2041 2297    2    9]
#  [ 627  883    0  256    3    0]
#  [ 627  883  230  486    3    1]
#  [ 627  883  460  716    3    2]
#  [ 627  883  690  946    3    3]
#  [ 627  883  920 1176    3    4]
#  [ 627  883 1150 1406    3    5]
#  [ 627  883 1380 1636    3    6]
#  [ 627  883 1610 1866    3    7]
#  [ 627  883 1840 2096    3    8]
#  [ 627  883 2041 2297    3    9]]
# HBox(children=(FloatProgress(value=0.0, max=1996.0), HTML(value='')))
