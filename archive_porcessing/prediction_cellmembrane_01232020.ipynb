# %% [markdown]
#  # Prediction
#  Keras on Tensorflow
#
#  This prediction runs on all 9 dataset.

# %%
import os, sys
import cv2
import numpy as np
import uuid
import tensorflow as tf
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
from imutils import paths
import itertools
import json
from pprint import pprint

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet
from core.metrics import iou_coef, dice_coef


from tensorflow.keras.models import load_model
from datetime import datetime

from core.imageprep import create_crop_idx, crop_to_patch, construct_from_patch, create_crop_idx_whole
from core.train_predict import stack_predict, stack_predict_v2
from tqdm.notebook import trange

from IPython import get_ipython
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %% [markdown]
#  ## Load Training Dataset

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# experiment
exp_name = 'dl_seg_project_raw'

# label
label = 'cell_membrane'

# trianing timestamp
training_date = '2019_12_06'
imginput_timestamp = '2019_12_06_17_06'
# model_training_timestamp = '2019_12_11_12_21'
model_training_timestamp = '2019_12_06_17_14'
print('Training timestamp: {}'.format(model_training_timestamp))

# input img path
imginput = os.path.join(exp_name, 'data_crop', imginput_timestamp)
imgpath = os.path.join(path, imginput)
print('Input Images Path: {}'.format(imgpath))

# model path
modelfd = 'model'
modelfn = 'model_' + model_training_timestamp + '.h5'
path_model = os.path.join(path, 'logs', modelfd, label, training_date, modelfn)
print('Model Path: {}'.format(path_model))

# raw path
rawfd = 'raw_input_image'
path_raw = os.path.join(path, rawfd)
print('Raw Path: {}'.format(path_raw))

# prediction path
pred_path = os.path.join(path, exp_name)
dir_checker('pred_img', pred_path)
# Out:
# Load Images...
# Training timestamp: 2019_12_06_17_14
# Input Images Path: D:PerlmutterData\dl_seg_project_raw\data_crop\2019_12_06_17_06
# Model Path: D:PerlmutterData\logs\model\cell_membrane\2019_12_06\model_2019_12_06_17_14.h5
# Raw Path: D:PerlmutterData\raw_input_image
# pred_img exists in D:PerlmutterData\dl_seg_project_raw

# %% [markdown]
# ## Parameter

# %%
# load parameter
parsfd = 'pars'
parsfn = 'pars_' + model_training_timestamp + '.json'
path_pars = os.path.join(path, 'logs', parsfd, label, training_date, parsfn)

with open(path_pars) as json_file:
    pars = json.load(json_file)

# %%
pprint(pars)
# Out:
# {'IMG_HEIGHT': 256,
#  'IMG_WIDTH': 256,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.1,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.1,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'epoch': 500,
#  'inputclass': ['cell_membrane'],
#  'learning_rate': 1e-05,
#  'loss': 'binary_crossentropy',
#  'metrics': ['accuracy'],
#  'seed': 100,
#  'timestamp': '2019_12_06_17_14',
#  'training_sample_size': 54100,
#  'validation_split': 0.1,
#  'validation_steps': 20}

# %%
label = pars['inputclass']
IMG_HEIGHT = pars['IMG_HEIGHT']
IMG_WIDTH = pars['IMG_WIDTH']

IMG_HEIGHT = 512
IMG_WIDTH = 512

# %% [markdown]
# ## Predict from Testing Dataset

# %%
# get dataset
rawfdlist = os.listdir(path_raw)
rawfdlist = list(rawfdlist[i] for i in [1])
print(rawfdlist)
# Out:
# ['data_d00_batch02_loc02']

# %%
rawimglist = {}
for folder in rawfdlist:
    print(folder)
    rawimglist[folder] = list(paths.list_images(os.path.join(path_raw, folder, 'image')))
# Out:
# data_d00_batch02_loc02

# %%
pprint(rawimglist)
# Out:
# {'data_d00_batch02_loc02': ['D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0001.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0002.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0003.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0004.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0005.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0006.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0007.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0008.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0009.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0010.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0011.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0012.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0013.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0014.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0015.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0016.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0017.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0018.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0019.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0020.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0021.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0022.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0023.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0024.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0025.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0026.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0027.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0028.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0029.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0030.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0031.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0032.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0033.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0034.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0035.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0036.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0037.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0038.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0039.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0040.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0041.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0042.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0043.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0044.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0045.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0046.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0047.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0048.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0049.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0050.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0051.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0052.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0053.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0054.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0055.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0056.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0057.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0058.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0059.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0060.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0061.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0062.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0063.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0064.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0065.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0066.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0067.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0068.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0069.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0070.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0071.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0072.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_0073.tif',
#                             'D:PerlmutterData\\raw_input_image\\data_d00_batch02_loc02\\image\\TH-4891 '
#                             '0day DOX D-K8_
640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 1 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 5 1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 5 2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 5 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, None, None, 1 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 5 2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 5 4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 5 2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 5 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 2 524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 2 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 1 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, None, None, 1 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
img_tmp = img * 1./255.
print(img_tmp.shape)
# Out:
# (705, 1779)

# %%
label = pars['inputclass'][0]
opdir = os.path.join(pred_path, 'pred_img')
fdnm_small = 'batch_small'

def checkpredfolder(rawfdlist, opdir, opfolder, label):
    # folder name
    dir_checker(label, opdir)
    img_path_small = os.path.join(opdir, label)
    dir_checker(opfolder, img_path_small)

    # create folder list
    for folder in rawfdlist:
        dir_checker(folder, os.path.join(img_path_small, opfolder))
'''
checkpredfolder(rawfdlist, opdir, fdnm_small, label)
'''
# Out:
# '\ncheckpredfolder(rawfdlist, opdir, fdnm_small, label)\n'

# %%
'''
from core.imageprep import create_crop_idx, crop_to_patch
from core.train_predict import stack_predict_v2

for idx in trange(len(rawfdlist)):
    
    folder = rawfdlist[idx]
    
    pred_input_imgs =  rawimglist_small[folder]
    pred_output_path = os.path.join(opdir, label, fdnm_small, folder)
    
    img = imread(rawimglist_small[folder][0])
    cropidx = create_crop_idx_whole(img.shape, (IMG_HEIGHT, IMG_WIDTH), overlap_fac = 0.1)
    # print(cropidx)
    
    stack_predict_v2(
                input_imgpath = pred_input_imgs, 
                output_imgpath = pred_output_path, 
                cropidx = cropidx, 
                model = model, 
                rescale = 1./255.,
                patch_size = (IMG_HEIGHT, IMG_WIDTH), 
                predict_threshold = 0.5)
'''
# Out:
# '\nfrom core.imageprep import create_crop_idx, crop_to_patch\nfrom core.train_predict import stack_predict_v2\n\nfor idx in trange(len(rawfdlist)):\n    \n    folder = rawfdlist[idx]\n    \n    pred_input_imgs =  rawimglist_small[folder]\n    pred_output_path = os.path.join(opdir, label, fdnm_small, folder)\n    \n    img = imread(rawimglist_small[folder][0])\n    cropidx = create_crop_idx_whole(img.shape, (IMG_HEIGHT, IMG_WIDTH), overlap_fac = 0.1)\n    # print(cropidx)\n    \n    stack_predict_v2(\n                input_imgpath = pred_input_imgs, \n                output_imgpath = pred_output_path, \n                cropidx = cropidx, \n                model = model, \n                rescale = 1./255.,\n                patch_size = (IMG_HEIGHT, IMG_WIDTH), \n                predict_threshold = 0.5)\n'

# %% [markdown]
# ## Prediction Small Dataset with tiles
# ### Create Folder

# %% [markdown]
# ## Prediction Small Dataset with tiles (whole stack)
# ### Create Folder

# %%
# folder name
fdnm_total = 'batch_total'
checkpredfolder(rawfdlist, opdir, fdnm_total, label)
# Out:
# cell_membrane exists in D:PerlmutterData\dl_seg_project_raw\pred_img
# batch_total exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane
# data_d00_batch02_loc02 exists in D:PerlmutterData\dl_seg_project_raw\pred_img\cell_membrane\batch_total

# %% [markdown]
# ### Tiling Prediction with Stack Input
# - Crop image into patched by a given overlap factor
# - Export a cropping index
# - Construct patches back into a image

# %%
from core.imageprep import create_crop_idx, crop_to_patch
from core.train_predict import stack_predict_v2

for idx in trange(len(rawfdlist)):
    
    folder = rawfdlist[idx]
    
    pred_input_imgs =  rawimglist[folder]
    pred_output_path = os.path.join(opdir, label, fdnm_total, folder)
    
    img = imread(rawimglist_small[folder][0])
    cropidx = create_crop_idx_whole(img.shape, (IMG_HEIGHT, IMG_WIDTH), overlap_fac = 0.1)
    # print(cropidx)
    
    stack_predict_v2(
                input_imgpath = pred_input_imgs, 
                output_imgpath = pred_output_path, 
                cropidx = cropidx, 
                model = model, 
                rescale = 1./255.,
                patch_size = (IMG_HEIGHT, IMG_WIDTH), 
                predict_threshold = 0.8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1857.0), HTML(value='')))
# C:\Users\wucci_admin\Documents\code\dl_fibem_seg\core\imageprep.py:554: RuntimeWarning: Mean of empty slice
#   outputimg = np.nanmean(img_stack_repos, axis = 0)
