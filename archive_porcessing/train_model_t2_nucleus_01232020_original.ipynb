# %% [markdown]
#  # Training Model
#  Keras on Tensorflow

# %%
import os, sys
import cv2
import numpy as np
import uuid
import tensorflow as tf
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
from imutils import paths
import itertools
import json
from pprint import pprint

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet
from core.metrics import iou_coef, dice_coef

from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau
from datetime import datetime

from IPython import get_ipython
# %load_ext autoreload
get_ipython().run_line_magic('load_ext', 'autoreload')
# %autoreload 2
get_ipython().run_line_magic('autoreload', '2')
# %load_ext tensorboard
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %%
sys.executable
# Out:
# 'C:\\Users\\wucci_admin\\Anaconda3\\envs\\tfdl02\\python.exe'

# %% [markdown]
#  ## Load Training Dataset

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# input set
crop_input_set = '2020_01_23_09_51_20x'
# crop_input_set = '2019_12_10_15_33_5x' # small training set

imginput = os.path.join('dl_seg_project_raw', 'data_crop', crop_input_set,)
imgpath = os.path.join(path, imginput)

print(imgpath)

img_dir = os.path.join(imgpath, 'images')
label_dir = os.path.join(imgpath, 'labels')
print(img_dir)
print(label_dir)

# check if the output folder exist. If not, create a folder
dir_checker('logs', path)
path_logs = os.path.join(path, 'logs')
dir_checker('fit', path_logs)
dir_checker('model', path_logs)
dir_checker('pars', path_logs)
# Out:
# Load Images...
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\labels
# logs exists in D:PerlmutterData
# fit exists in D:PerlmutterData\logs
# model exists in D:PerlmutterData\logs
# pars exists in D:PerlmutterData\logs

# %% [markdown]
#  Print the first file name.

# %%
imgpath_all = list(paths.list_images(imgpath))
print(imgpath_all[0])
# Out:
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images\nucleus\0001.tif

# %% [markdown]
#  ## Create Image Datagenerator
#  1. create only one datagen
#  2. specify valiation split in datagen argument
#  3. add split data when calling `datagen.flow_from_directory`

# %%
timestamp = datetime.now().strftime("%Y_%m_%d_%H_%M")
date =  datetime.now().strftime("%Y_%m_%d")
seed = 102
batch_size = 16
epoch = 500
validation_steps = 20
validation_split = 0.3
training_sample_size = len(imgpath_all)
IMG_HEIGHT = None
IMG_WIDTH = None
classes = ['cell_membrane', 'nucleus', 'autophagosome']
inputclass = [classes[1]]
learning_rate = 1e-4
loss = "binary_crossentropy"
metrics = ['accuracy', iou_coef, dice_coef]

metrics_name = []
for f in metrics:
    if callable(f):
        metrics_name.append(f.__name__)
    else:
        metrics_name.append(f)

# %%
# create arguments for data generator
data_gen_img_args = dict(
                # featurewise_center = True,
                # featurewise_std_normalization = True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                rescale=1.0/255.0,
                )

data_gen_label_args = dict(
                # featurewise_center=True,
                # featurewise_std_normalization=True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                # rescale=1.0/255.0,
                rescale=1.0/255.0,
                )

# create parameter
pars = dict(
                # basic information
                timestamp = timestamp,
                date = date,
                seed = seed,
                batch_size = batch_size,
                
                # Data generator
                crop_input_set = crop_input_set,
                validation_steps = validation_steps,
                validation_split = validation_split,
                training_sample_size = training_sample_size,
                
                # training class
                classes = classes,
                inputclass = inputclass,
    
                # add datagen args
                data_gen_img_args = data_gen_img_args,
                data_gen_label_args = data_gen_label_args,
                
                # Build model
                IMG_HEIGHT = IMG_HEIGHT,
                IMG_WIDTH = IMG_WIDTH,
                epoch = epoch, 
                loss = loss,
                metrics_name = metrics_name,
                learning_rate = learning_rate,
                )

# save parameter
path_pars = os.path.join(path_logs, 'pars')
dir_checker(inputclass[0], path_pars)
dir_checker(date, os.path.join(path_pars, inputclass[0]))

pprint(pars)
# Out:
# nucleus exists in D:PerlmutterData\logs\pars
# 2020_01_23 exists in D:PerlmutterData\logs\pars\nucleus
# {'IMG_HEIGHT': None,
#  'IMG_WIDTH': None,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'crop_input_set': '2020_01_23_09_51_20x',
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.3,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.3,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'date': '2020_01_23',
#  'epoch': 500,
#  'inputclass': ['nucleus'],
#  'learning_rate': 0.0001,
#  'loss': 'binary_crossentropy',
#  'metrics_name': ['accuracy', 'iou_coef', 'dice_coef'],
#  'seed': 102,
#  'timestamp': '2020_01_23_17_15',
#  'training_sample_size': 13240,
#  'validation_split': 0.3,
#  'validation_steps': 20}

# %%
par_file_dir = os.path.join(path_pars, inputclass[0], date, 'pars_' + timestamp + '.json')
print(par_file_dir)

with open(par_file_dir, 'w') as outfile:
    json.dump(pars, outfile, indent=4)
# Out:
# D:PerlmutterData\logs\pars\nucleus\2020_01_23\pars_2020_01_23_17_15.json

# %%
# create generator
image_datagen = ImageDataGenerator(**data_gen_img_args)
label_datagen = ImageDataGenerator(**data_gen_label_args)

# %%
# load images into generator
train_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training', # <- define subset as 'training'
    seed=seed)

train_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training',
    seed=seed)

valid_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation', # <- define subset as 'validation'
    seed=seed)

valid_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation',
    seed=seed)
# Out:
# Found 4634 images belonging to 1 classes.
# Found 4634 images belonging to 1 classes.
# Found 1986 images belonging to 1 classes.
# Found 1986 images belonging to 1 classes.

# %%
# merge image and label generator
def combine_generator(gen1, gen2):
    while True:
        yield(gen1.next(), gen2.next()) 
train_generator = combine_generator(train_image_generator, train_label_generator)
valid_generator = combine_generator(valid_image_generator, valid_label_generator)

# %%
'''
train_generator = zip(train_image_generator, train_label_generator)
valid_generator = zip(valid_image_generator, valid_label_generator)
'''
# Out:
# '\ntrain_generator = zip(train_image_generator, train_label_generator)\nvalid_generator = zip(valid_image_generator, valid_label_generator)\n'

# %% [markdown]
#  ## Training

# %%
print("Start training...")
# Out:
# Start training...

# %% [markdown]
#  ### Define Callbacks

# %%
# checkpoint
modelfilename = 'model_' + timestamp + '.h5'
dir_checker(inputclass[0], os.path.join(path_logs, 'model'))
dir_checker(date, os.path.join(path_logs, 'model', inputclass[0]))
modelfile_path = os.path.join(path_logs, 'model', inputclass[0], date, modelfilename)

checkpointer = ModelCheckpoint(filepath = modelfile_path, 
                               monitor = 'val_loss', 
                               mode = 'min', 
                               verbose = 1, 
                               save_best_only = True)

# early stopping 
early_stopping = EarlyStopping(monitor='val_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4)

# learning rate adjustment
reduceLR = ReduceLROnPlateau(monitor='val_loss',
                    factor=0.1,
                    patience=4,
                    verbose=1,
                    min_delta=1e-4)

# tensorboard
from tensorflow.summary import create_file_writer

dir_checker(inputclass[0], os.path.join(path_logs, 'fit'))
dir_checker(date, os.path.join(path_logs, 'fit', inputclass[0]))
logdir = os.path.join(path_logs, 'fit', inputclass[0], date, timestamp)

file_writer = create_file_writer(logdir + "/metrics")
file_writer.set_as_default()

metrics = ['accuracy', iou_coef, dice_coef]


tensorboard_callback = TensorBoard(log_dir = logdir, 
                                   profile_batch = 0, 
                                   update_freq= 500,
                                   histogram_freq = 1
                                   )

# compile callbacks
# callbacks = [checkpointer, tensorboard_callback, early_stopping, reduceLR]
callbacks = [checkpointer, tensorboard_callback, reduceLR]
# Out:
# nucleus exists in D:PerlmutterData\logs\model
# 2020_01_23 exists in D:PerlmutterData\logs\model\nucleus
# nucleus exists in D:PerlmutterData\logs\fit
# 2020_01_23 exists in D:PerlmutterData\logs\fit\nucleus

# %% [markdown]
#  ### Setup the model

# %%
# calculate steps_per_epoch
steps_per_epoch = training_sample_size * (1 - validation_split) // batch_size
print("Steps per epoch: {}".format(steps_per_epoch))
# Out:
# Steps per epoch: 579.0

# %%
print(logdir)
# Out:
# D:PerlmutterData\logs\fit\nucleus\2020_01_23\2020_01_23_17_15

# %%
# prepare the model
unetmodel = UNet(shape = (IMG_HEIGHT, IMG_WIDTH), 
                 lr = learning_rate, 
                 loss = loss,
                 metrics = metrics,
                )

# train the model
unetmodel.fit_generator(
                    generator = train_generator, 
                    validation_data = valid_generator,
                    validation_steps = validation_steps,
                    steps_per_epoch = steps_per_epoch,
                    epochs = epoch,  
                    callbacks = callbacks,
                    verbose = 1, 
                    )
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 1 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 5 1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 5 2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 5 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, None, None, 1 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 5 2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 5 4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 5 2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 5 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 2 524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 2 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 1 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, None, None, 1 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 578/579 [============================>.] - ETA: 1s - loss: 0.5996 - accuracy: 0.7214 - iou_coef: 0.0934 - dice_coef: 0.1482
# Epoch 00001: val_loss improved from inf to 0.79914, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 592s 1s/step - loss: 0.5995 - accuracy: 0.7214 - iou_coef: 0.0933 - dice_coef: 0.1481 - val_loss: 0.7991 - val_accuracy: 0.5432 - val_iou_coef: 0.1244 - val_dice_coef: 0.2036
# Epoch 2/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.5430 - accuracy: 0.7237 - iou_coef: 0.1066 - dice_coef: 0.1635
# Epoch 00002: val_loss improved from 0.79914 to 0.76477, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 582s 1s/step - loss: 0.5433 - accuracy: 0.7234 - iou_coef: 0.1067 - dice_coef: 0.1637 - val_loss: 0.7648 - val_accuracy: 0.5797 - val_iou_coef: 0.1401 - val_dice_coef: 0.2200
# Epoch 3/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.5181 - accuracy: 0.7320 - iou_coef: 0.1148 - dice_coef: 0.1719
# Epoch 00003: val_loss improved from 0.76477 to 0.62922, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 582s 1s/step - loss: 0.5182 - accuracy: 0.7319 - iou_coef: 0.1149 - dice_coef: 0.1720 - val_loss: 0.6292 - val_accuracy: 0.5926 - val_iou_coef: 0.1742 - val_dice_coef: 0.2594
# Epoch 4/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.4491 - accuracy: 0.7988 - iou_coef: 0.1518 - dice_coef: 0.2057
# Epoch 00004: val_loss did not improve from 0.62922
# 579/579 [==============================] - 579s 1s/step - loss: 0.4492 - accuracy: 0.7988 - iou_coef: 0.1519 - dice_coef: 0.2058 - val_loss: 0.7180 - val_accuracy: 0.7274 - val_iou_coef: 0.2309 - val_dice_coef: 0.3035
# Epoch 5/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.2814 - accuracy: 0.8992 - iou_coef: 0.2333 - dice_coef: 0.2744
# Epoch 00005: val_loss improved from 0.62922 to 0.26330, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 581s 1s/step - loss: 0.2816 - accuracy: 0.8991 - iou_coef: 0.2331 - dice_coef: 0.2742 - val_loss: 0.2633 - val_accuracy: 0.9178 - val_iou_coef: 0.3737 - val_dice_coef: 0.4482
# Epoch 6/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.2032 - accuracy: 0.9357 - iou_coef: 0.2722 - dice_coef: 0.3048
# Epoch 00006: val_loss did not improve from 0.26330
# 579/579 [==============================] - 578s 999ms/step - loss: 0.2033 - accuracy: 0.9356 - iou_coef: 0.2721 - dice_coef: 0.3047 - val_loss: 0.3493 - val_accuracy: 0.8958 - val_iou_coef: 0.3789 - val_dice_coef: 0.4309
# Epoch 7/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1865 - accuracy: 0.9429 - iou_coef: 0.2863 - dice_coef: 0.3169
# Epoch 00007: val_loss did not improve from 0.26330
# 579/579 [==============================] - 579s 1s/step - loss: 0.1864 - accuracy: 0.9430 - iou_coef: 0.2862 - dice_coef: 0.3169 - val_loss: 0.3071 - val_accuracy: 0.8927 - val_iou_coef: 0.3860 - val_dice_coef: 0.4420
# Epoch 8/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1776 - accuracy: 0.9458 - iou_coef: 0.2913 - dice_coef: 0.3202
# Epoch 00008: val_loss did not improve from 0.26330
# 579/579 [==============================] - 579s 999ms/step - loss: 0.1779 - accuracy: 0.9457 - iou_coef: 0.2913 - dice_coef: 0.3203 - val_loss: 0.2944 - val_accuracy: 0.9071 - val_iou_coef: 0.3983 - val_dice_coef: 0.4372
# Epoch 9/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1637 - accuracy: 0.9516 - iou_coef: 0.2992 - dice_coef: 0.3264
# Epoch 00009: val_loss improved from 0.26330 to 0.23746, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 580s 1s/step - loss: 0.1636 - accuracy: 0.9516 - iou_coef: 0.2994 - dice_coef: 0.3266 - val_loss: 0.2375 - val_accuracy: 0.9206 - val_iou_coef: 0.4344 - val_dice_coef: 0.4853
# Epoch 10/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1613 - accuracy: 0.9512 - iou_coef: 0.3016 - dice_coef: 0.3287
# Epoch 00010: val_loss did not improve from 0.23746
# 579/579 [==============================] - 579s 999ms/step - loss: 0.1612 - accuracy: 0.9513 - iou_coef: 0.3018 - dice_coef: 0.3291 - val_loss: 0.2711 - val_accuracy: 0.9197 - val_iou_coef: 0.4125 - val_dice_coef: 0.4563
# Epoch 11/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9510 - iou_coef: 0.3013 - dice_coef: 0.3279
# Epoch 00011: val_loss improved from 0.23746 to 0.18610, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_23\model_2020_01_23_17_15.h5
# 579/579 [==============================] - 577s 997ms/step - loss: 0.1606 - accuracy: 0.9510 - iou_coef: 0.3013 - dice_coef: 0.3279 - val_loss: 0.1861 - val_accuracy: 0.9376 - val_iou_coef: 0.4748 - val_dice_coef: 0.5160
# Epoch 12/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1597 - accuracy: 0.9518 - iou_coef: 0.3046 - dice_coef: 0.3317
# Epoch 00012: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.1601 - accuracy: 0.9517 - iou_coef: 0.3044 - dice_coef: 0.3314 - val_loss: 0.2002 - val_accuracy: 0.9381 - val_iou_coef: 0.4576 - val_dice_coef: 0.4944
# Epoch 13/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1490 - accuracy: 0.9546 - iou_coef: 0.3106 - dice_coef: 0.3361
# Epoch 00013: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.1491 - accuracy: 0.9546 - iou_coef: 0.3107 - dice_coef: 0.3363 - val_loss: 0.2567 - val_accuracy: 0.9161 - val_iou_coef: 0.3906 - val_dice_coef: 0.4217
# Epoch 14/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9544 - iou_coef: 0.3122 - dice_coef: 0.3374
# Epoch 00014: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.1483 - accuracy: 0.9541 - iou_coef: 0.3121 - dice_coef: 0.3373 - val_loss: 0.2024 - val_accuracy: 0.9223 - val_iou_coef: 0.3977 - val_dice_coef: 0.4483
# Epoch 15/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1521 - accuracy: 0.9529 - iou_coef: 0.3056 - dice_coef: 0.3317
# Epoch 00015: val_loss did not improve from 0.18610
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 579/579 [==============================] - 572s 989ms/step - loss: 0.1519 - accuracy: 0.9529 - iou_coef: 0.3058 - dice_coef: 0.3318 - val_loss: 0.4509 - val_accuracy: 0.8864 - val_iou_coef: 0.3988 - val_dice_coef: 0.4317
# Epoch 16/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9633 - iou_coef: 0.3277 - dice_coef: 0.3487
# Epoch 00016: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.1119 - accuracy: 0.9632 - iou_coef: 0.3278 - dice_coef: 0.3488 - val_loss: 0.3218 - val_accuracy: 0.8960 - val_iou_coef: 0.3971 - val_dice_coef: 0.4383
# Epoch 17/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0991 - accuracy: 0.9664 - iou_coef: 0.3389 - dice_coef: 0.3583
# Epoch 00017: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0990 - accuracy: 0.9664 - iou_coef: 0.3390 - dice_coef: 0.3584 - val_loss: 0.3436 - val_accuracy: 0.8746 - val_iou_coef: 0.3994 - val_dice_coef: 0.4472
# Epoch 18/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0952 - accuracy: 0.9675 - iou_coef: 0.3424 - dice_coef: 0.3612
# Epoch 00018: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0954 - accuracy: 0.9674 - iou_coef: 0.3424 - dice_coef: 0.3612 - val_loss: 0.3836 - val_accuracy: 0.8600 - val_iou_coef: 0.4038 - val_dice_coef: 0.4517
# Epoch 19/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9681 - iou_coef: 0.3529 - dice_coef: 0.3717
# Epoch 00019: val_loss did not improve from 0.18610
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0911 - accuracy: 0.9682 - iou_coef: 0.3531 - dice_coef: 0.3719 - val_loss: 0.3160 - val_accuracy: 0.8951 - val_iou_coef: 0.4025 - val_dice_coef: 0.4414
# Epoch 20/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0867 - accuracy: 0.9694 - iou_coef: 0.3530 - dice_coef: 0.3713
# Epoch 00020: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0866 - accuracy: 0.9694 - iou_coef: 0.3532 - dice_coef: 0.3715 - val_loss: 0.3815 - val_accuracy: 0.8692 - val_iou_coef: 0.3290 - val_dice_coef: 0.3706
# Epoch 21/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0844 - accuracy: 0.9705 - iou_coef: 0.3585 - dice_coef: 0.3770
# Epoch 00021: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0843 - accuracy: 0.9705 - iou_coef: 0.3582 - dice_coef: 0.3768 - val_loss: 0.3305 - val_accuracy: 0.8813 - val_iou_coef: 0.4110 - val_dice_coef: 0.4528
# Epoch 22/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9700 - iou_coef: 0.3543 - dice_coef: 0.3725
# Epoch 00022: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0848 - accuracy: 0.9700 - iou_coef: 0.3542 - dice_coef: 0.3724 - val_loss: 0.3972 - val_accuracy: 0.8641 - val_iou_coef: 0.4126 - val_dice_coef: 0.4528
# Epoch 23/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9711 - iou_coef: 0.3596 - dice_coef: 0.3774
# Epoch 00023: val_loss did not improve from 0.18610
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0825 - accuracy: 0.9711 - iou_coef: 0.3595 - dice_coef: 0.3772 - val_loss: 0.3750 - val_accuracy: 0.8708 - val_iou_coef: 0.3514 - val_dice_coef: 0.3919
# Epoch 24/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9700 - iou_coef: 0.3611 - dice_coef: 0.3794
# Epoch 00024: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0837 - accuracy: 0.9700 - iou_coef: 0.3612 - dice_coef: 0.3795 - val_loss: 0.3698 - val_accuracy: 0.8779 - val_iou_coef: 0.3717 - val_dice_coef: 0.4120
# Epoch 25/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9708 - iou_coef: 0.3619 - dice_coef: 0.3802
# Epoch 00025: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0826 - accuracy: 0.9708 - iou_coef: 0.3619 - dice_coef: 0.3802 - val_loss: 0.3835 - val_accuracy: 0.8748 - val_iou_coef: 0.3812 - val_dice_coef: 0.4228
# Epoch 26/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0815 - accuracy: 0.9710 - iou_coef: 0.3631 - dice_coef: 0.3813
# Epoch 00026: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.0816 - accuracy: 0.9710 - iou_coef: 0.3630 - dice_coef: 0.3812 - val_loss: 0.3351 - val_accuracy: 0.8854 - val_iou_coef: 0.3856 - val_dice_coef: 0.4254
# Epoch 27/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9699 - iou_coef: 0.3592 - dice_coef: 0.3771
# Epoch 00027: val_loss did not improve from 0.18610
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0837 - accuracy: 0.9699 - iou_coef: 0.3592 - dice_coef: 0.3771 - val_loss: 0.4106 - val_accuracy: 0.8623 - val_iou_coef: 0.3904 - val_dice_coef: 0.4339
# Epoch 28/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9702 - iou_coef: 0.3609 - dice_coef: 0.3789
# Epoch 00028: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0837 - accuracy: 0.9701 - iou_coef: 0.3610 - dice_coef: 0.3791 - val_loss: 0.3792 - val_accuracy: 0.8704 - val_iou_coef: 0.3805 - val_dice_coef: 0.4280
# Epoch 29/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0808 - accuracy: 0.9714 - iou_coef: 0.3627 - dice_coef: 0.3806
# Epoch 00029: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0807 - accuracy: 0.9715 - iou_coef: 0.3628 - dice_coef: 0.3806 - val_loss: 0.4119 - val_accuracy: 0.8625 - val_iou_coef: 0.4159 - val_dice_coef: 0.4545
# Epoch 30/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9700 - iou_coef: 0.3626 - dice_coef: 0.3806
# Epoch 00030: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.0836 - accuracy: 0.9700 - iou_coef: 0.3622 - dice_coef: 0.3803 - val_loss: 0.4106 - val_accuracy: 0.8518 - val_iou_coef: 0.3609 - val_dice_coef: 0.4032
# Epoch 31/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9709 - iou_coef: 0.3618 - dice_coef: 0.3797
# Epoch 00031: val_loss did not improve from 0.18610
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0828 - accuracy: 0.9709 - iou_coef: 0.3619 - dice_coef: 0.3799 - val_loss: 0.3577 - val_accuracy: 0.8799 - val_iou_coef: 0.3936 - val_dice_coef: 0.4305
# Epoch 32/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9706 - iou_coef: 0.3609 - dice_coef: 0.3787
# Epoch 00032: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0825 - accuracy: 0.9706 - iou_coef: 0.3614 - dice_coef: 0.3792 - val_loss: 0.3797 - val_accuracy: 0.8681 - val_iou_coef: 0.4008 - val_dice_coef: 0.4442
# Epoch 33/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0815 - accuracy: 0.9709 - iou_coef: 0.3619 - dice_coef: 0.3799
# Epoch 00033: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0814 - accuracy: 0.9709 - iou_coef: 0.3617 - dice_coef: 0.3796 - val_loss: 0.4171 - val_accuracy: 0.8567 - val_iou_coef: 0.3451 - val_dice_coef: 0.3836
# Epoch 34/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9714 - iou_coef: 0.3605 - dice_coef: 0.3785
# Epoch 00034: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0795 - accuracy: 0.9714 - iou_coef: 0.3606 - dice_coef: 0.3786 - val_loss: 0.2944 - val_accuracy: 0.8870 - val_iou_coef: 0.4073 - val_dice_coef: 0.4495
# Epoch 35/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9697 - iou_coef: 0.3633 - dice_coef: 0.3817
# Epoch 00035: val_loss did not improve from 0.18610
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0847 - accuracy: 0.9696 - iou_coef: 0.3632 - dice_coef: 0.3816 - val_loss: 0.4076 - val_accuracy: 0.8610 - val_iou_coef: 0.3918 - val_dice_coef: 0.4300
# Epoch 36/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0834 - accuracy: 0.9703 - iou_coef: 0.3599 - dice_coef: 0.3778
# Epoch 00036: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0834 - accuracy: 0.9704 - iou_coef: 0.3598 - dice_coef: 0.3777 - val_loss: 0.3295 - val_accuracy: 0.8780 - val_iou_coef: 0.3511 - val_dice_coef: 0.3927
# Epoch 37/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9706 - iou_coef: 0.3624 - dice_coef: 0.3805
# Epoch 00037: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0829 - accuracy: 0.9706 - iou_coef: 0.3625 - dice_coef: 0.3806 - val_loss: 0.4016 - val_accuracy: 0.8616 - val_iou_coef: 0.3923 - val_dice_coef: 0.4376
# Epoch 38/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9709 - iou_coef: 0.3596 - dice_coef: 0.3775
# Epoch 00038: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0826 - accuracy: 0.9710 - iou_coef: 0.3598 - dice_coef: 0.3777 - val_loss: 0.4560 - val_accuracy: 0.8419 - val_iou_coef: 0.3684 - val_dice_coef: 0.4091
# Epoch 39/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9704 - iou_coef: 0.3605 - dice_coef: 0.3785
# Epoch 00039: val_loss did not improve from 0.18610
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0825 - accuracy: 0.9703 - iou_coef: 0.3605 - dice_coef: 0.3785 - val_loss: 0.4086 - val_accuracy: 0.8557 - val_iou_coef: 0.3786 - val_dice_coef: 0.4177
# Epoch 40/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9706 - iou_coef: 0.3614 - dice_coef: 0.3797
# Epoch 00040: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 989ms/step - loss: 0.0819 - accuracy: 0.9706 - iou_coef: 0.3614 - dice_coef: 0.3797 - val_loss: 0.3611 - val_accuracy: 0.8707 - val_iou_coef: 0.3604 - val_dice_coef: 0.4020
# Epoch 41/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0834 - accuracy: 0.9705 - iou_coef: 0.3600 - dice_coef: 0.3779
# Epoch 00041: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0834 - accuracy: 0.9705 - iou_coef: 0.3598 - dice_coef: 0.3777 - val_loss: 0.3526 - val_accuracy: 0.8829 - val_iou_coef: 0.3665 - val_dice_coef: 0.4042
# Epoch 42/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9712 - iou_coef: 0.3646 - dice_coef: 0.3826
# Epoch 00042: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0820 - accuracy: 0.9712 - iou_coef: 0.3645 - dice_coef: 0.3824 - val_loss: 0.3766 - val_accuracy: 0.8660 - val_iou_coef: 0.4082 - val_dice_coef: 0.4542
# Epoch 43/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9713 - iou_coef: 0.3591 - dice_coef: 0.3772
# Epoch 00043: val_loss did not improve from 0.18610
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 9.999999092680235e-13.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0806 - accuracy: 0.9714 - iou_coef: 0.3594 - dice_coef: 0.3775 - val_loss: 0.4310 - val_accuracy: 0.8494 - val_iou_coef: 0.3713 - val_dice_coef: 0.4154
# Epoch 44/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9705 - iou_coef: 0.3604 - dice_coef: 0.3785
# Epoch 00044: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0825 - accuracy: 0.9705 - iou_coef: 0.3604 - dice_coef: 0.3786 - val_loss: 0.3882 - val_accuracy: 0.8640 - val_iou_coef: 0.4125 - val_dice_coef: 0.4549
# Epoch 45/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0804 - accuracy: 0.9715 - iou_coef: 0.3639 - dice_coef: 0.3820
# Epoch 00045: val_loss did not improve from 0.18610
# 579/579 [==============================] - 575s 993ms/step - loss: 0.0803 - accuracy: 0.9715 - iou_coef: 0.3638 - dice_coef: 0.3819 - val_loss: 0.4377 - val_accuracy: 0.8544 - val_iou_coef: 0.3862 - val_dice_coef: 0.4267
# Epoch 46/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9697 - iou_coef: 0.3652 - dice_coef: 0.3836
# Epoch 00046: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0846 - accuracy: 0.9697 - iou_coef: 0.3652 - dice_coef: 0.3836 - val_loss: 0.3161 - val_accuracy: 0.8877 - val_iou_coef: 0.3519 - val_dice_coef: 0.3925
# Epoch 47/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9711 - iou_coef: 0.3586 - dice_coef: 0.3768
# Epoch 00047: val_loss did not improve from 0.18610
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.9999988758398e-14.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0817 - accuracy: 0.9711 - iou_coef: 0.3588 - dice_coef: 0.3769 - val_loss: 0.3910 - val_accuracy: 0.8667 - val_iou_coef: 0.3702 - val_dice_coef: 0.4063
# Epoch 48/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9710 - iou_coef: 0.3609 - dice_coef: 0.3790
# Epoch 00048: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0817 - accuracy: 0.9710 - iou_coef: 0.3608 - dice_coef: 0.3790 - val_loss: 0.4385 - val_accuracy: 0.8497 - val_iou_coef: 0.3739 - val_dice_coef: 0.4146
# Epoch 49/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9712 - iou_coef: 0.3643 - dice_coef: 0.3823
# Epoch 00049: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0813 - accuracy: 0.9712 - iou_coef: 0.3645 - dice_coef: 0.3825 - val_loss: 0.3559 - val_accuracy: 0.8756 - val_iou_coef: 0.4209 - val_dice_coef: 0.4647
# Epoch 50/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0816 - accuracy: 0.9711 - iou_coef: 0.3593 - dice_coef: 0.3771
# Epoch 00050: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0816 - accuracy: 0.9711 - iou_coef: 0.3592 - dice_coef: 0.3770 - val_loss: 0.3731 - val_accuracy: 0.8679 - val_iou_coef: 0.4027 - val_dice_coef: 0.4442
# Epoch 51/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9704 - iou_coef: 0.3632 - dice_coef: 0.3812
# Epoch 00051: val_loss did not improve from 0.18610
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 9.999999146890344e-15.
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0829 - accuracy: 0.9705 - iou_coef: 0.3632 - dice_coef: 0.3812 - val_loss: 0.3229 - val_accuracy: 0.8799 - val_iou_coef: 0.3785 - val_dice_coef: 0.4160
# Epoch 52/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9712 - iou_coef: 0.3591 - dice_coef: 0.3768
# Epoch 00052: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0816 - accuracy: 0.9713 - iou_coef: 0.3590 - dice_coef: 0.3767 - val_loss: 0.4010 - val_accuracy: 0.8554 - val_iou_coef: 0.3706 - val_dice_coef: 0.4181
# Epoch 53/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9706 - iou_coef: 0.3623 - dice_coef: 0.3804
# Epoch 00053: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0824 - accuracy: 0.9707 - iou_coef: 0.3624 - dice_coef: 0.3805 - val_loss: 0.3977 - val_accuracy: 0.8605 - val_iou_coef: 0.3850 - val_dice_coef: 0.4339
# Epoch 54/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9716 - iou_coef: 0.3595 - dice_coef: 0.3773
# Epoch 00054: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 989ms/step - loss: 0.0805 - accuracy: 0.9715 - iou_coef: 0.3595 - dice_coef: 0.3773 - val_loss: 0.3823 - val_accuracy: 0.8695 - val_iou_coef: 0.3643 - val_dice_coef: 0.4015
# Epoch 55/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9719 - iou_coef: 0.3615 - dice_coef: 0.3790
# Epoch 00055: val_loss did not improve from 0.18610
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 9.999998977483753e-16.
# 579/579 [==============================] - 572s 988ms/step - loss: 0.0804 - accuracy: 0.9719 - iou_coef: 0.3615 - dice_coef: 0.3791 - val_loss: 0.4804 - val_accuracy: 0.8297 - val_iou_coef: 0.3996 - val_dice_coef: 0.4456
# Epoch 56/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9701 - iou_coef: 0.3620 - dice_coef: 0.3802
# Epoch 00056: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0839 - accuracy: 0.9701 - iou_coef: 0.3620 - dice_coef: 0.3802 - val_loss: 0.3264 - val_accuracy: 0.8770 - val_iou_coef: 0.4004 - val_dice_coef: 0.4471
# Epoch 57/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9704 - iou_coef: 0.3632 - dice_coef: 0.3816
# Epoch 00057: val_loss did not improve from 0.18610
# 579/579 [==============================] - 575s 992ms/step - loss: 0.0823 - accuracy: 0.9704 - iou_coef: 0.3634 - dice_coef: 0.3818 - val_loss: 0.4389 - val_accuracy: 0.8508 - val_iou_coef: 0.4020 - val_dice_coef: 0.4475
# Epoch 58/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9711 - iou_coef: 0.3566 - dice_coef: 0.3745
# Epoch 00058: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0818 - accuracy: 0.9712 - iou_coef: 0.3568 - dice_coef: 0.3746 - val_loss: 0.3723 - val_accuracy: 0.8722 - val_iou_coef: 0.3881 - val_dice_coef: 0.4267
# Epoch 59/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9703 - iou_coef: 0.3632 - dice_coef: 0.3818
# Epoch 00059: val_loss did not improve from 0.18610
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 9.999998977483754e-17.
# 579/579 [==============================] - 575s 993ms/step - loss: 0.0839 - accuracy: 0.9703 - iou_coef: 0.3633 - dice_coef: 0.3818 - val_loss: 0.4327 - val_accuracy: 0.8573 - val_iou_coef: 0.3852 - val_dice_coef: 0.4258
# Epoch 60/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9709 - iou_coef: 0.3607 - dice_coef: 0.3787
# Epoch 00060: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0822 - accuracy: 0.9709 - iou_coef: 0.3606 - dice_coef: 0.3786 - val_loss: 0.3759 - val_accuracy: 0.8694 - val_iou_coef: 0.3772 - val_dice_coef: 0.4160
# Epoch 61/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9705 - iou_coef: 0.3614 - dice_coef: 0.3794
# Epoch 00061: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0825 - accuracy: 0.9705 - iou_coef: 0.3614 - dice_coef: 0.3794 - val_loss: 0.4349 - val_accuracy: 0.8600 - val_iou_coef: 0.3806 - val_dice_coef: 0.4222
# Epoch 62/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9702 - iou_coef: 0.3636 - dice_coef: 0.3822
# Epoch 00062: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0827 - accuracy: 0.9702 - iou_coef: 0.3638 - dice_coef: 0.3823 - val_loss: 0.4227 - val_accuracy: 0.8521 - val_iou_coef: 0.3718 - val_dice_coef: 0.4155
# Epoch 63/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0791 - accuracy: 0.9719 - iou_coef: 0.3573 - dice_coef: 0.3748
# Epoch 00063: val_loss did not improve from 0.18610
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 9.999998845134856e-18.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0790 - accuracy: 0.9719 - iou_coef: 0.3575 - dice_coef: 0.3750 - val_loss: 0.3694 - val_accuracy: 0.8658 - val_iou_coef: 0.3972 - val_dice_coef: 0.4417
# Epoch 64/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9699 - iou_coef: 0.3640 - dice_coef: 0.3824
# Epoch 00064: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0851 - accuracy: 0.9700 - iou_coef: 0.3641 - dice_coef: 0.3825 - val_loss: 0.4464 - val_accuracy: 0.8467 - val_iou_coef: 0.4155 - val_dice_coef: 0.4587
# Epoch 65/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9708 - iou_coef: 0.3594 - dice_coef: 0.3776
# Epoch 00065: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0822 - accuracy: 0.9708 - iou_coef: 0.3596 - dice_coef: 0.3778 - val_loss: 0.3111 - val_accuracy: 0.8860 - val_iou_coef: 0.3908 - val_dice_coef: 0.4318
# Epoch 66/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9710 - iou_coef: 0.3641 - dice_coef: 0.3823
# Epoch 00066: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0810 - accuracy: 0.9710 - iou_coef: 0.3641 - dice_coef: 0.3823 - val_loss: 0.3844 - val_accuracy: 0.8689 - val_iou_coef: 0.3612 - val_dice_coef: 0.4008
# Epoch 67/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9704 - iou_coef: 0.3606 - dice_coef: 0.3785
# Epoch 00067: val_loss did not improve from 0.18610
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 9.999999010570977e-19.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0821 - accuracy: 0.9704 - iou_coef: 0.3604 - dice_coef: 0.3783 - val_loss: 0.4276 - val_accuracy: 0.8582 - val_iou_coef: 0.3572 - val_dice_coef: 0.3972
# Epoch 68/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9709 - iou_coef: 0.3594 - dice_coef: 0.3774
# Epoch 00068: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0819 - accuracy: 0.9710 - iou_coef: 0.3597 - dice_coef: 0.3777 - val_loss: 0.3883 - val_accuracy: 0.8635 - val_iou_coef: 0.3722 - val_dice_coef: 0.4158
# Epoch 69/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9700 - iou_coef: 0.3633 - dice_coef: 0.3820
# Epoch 00069: val_loss did not improve from 0.18610
# 579/579 [==============================] - 575s 992ms/step - loss: 0.0843 - accuracy: 0.9700 - iou_coef: 0.3629 - dice_coef: 0.3817 - val_loss: 0.4346 - val_accuracy: 0.8542 - val_iou_coef: 0.3982 - val_dice_coef: 0.4383
# Epoch 70/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9709 - iou_coef: 0.3581 - dice_coef: 0.3758
# Epoch 00070: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0820 - accuracy: 0.9709 - iou_coef: 0.3585 - dice_coef: 0.3763 - val_loss: 0.4282 - val_accuracy: 0.8571 - val_iou_coef: 0.3865 - val_dice_coef: 0.4352
# Epoch 71/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9700 - iou_coef: 0.3603 - dice_coef: 0.3783
# Epoch 00071: val_loss did not improve from 0.18610
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 9.999999424161285e-20.
# 579/579 [==============================] - 575s 993ms/step - loss: 0.0834 - accuracy: 0.9701 - iou_coef: 0.3606 - dice_coef: 0.3786 - val_loss: 0.2853 - val_accuracy: 0.8979 - val_iou_coef: 0.3601 - val_dice_coef: 0.4006
# Epoch 72/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9711 - iou_coef: 0.3613 - dice_coef: 0.3791
# Epoch 00072: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0808 - accuracy: 0.9711 - iou_coef: 0.3614 - dice_coef: 0.3792 - val_loss: 0.4849 - val_accuracy: 0.8476 - val_iou_coef: 0.3788 - val_dice_coef: 0.4213
# Epoch 73/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9717 - iou_coef: 0.3650 - dice_coef: 0.3832
# Epoch 00073: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0816 - accuracy: 0.9716 - iou_coef: 0.3650 - dice_coef: 0.3832 - val_loss: 0.3528 - val_accuracy: 0.8750 - val_iou_coef: 0.4103 - val_dice_coef: 0.4522
# Epoch 74/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9702 - iou_coef: 0.3568 - dice_coef: 0.3750
# Epoch 00074: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0828 - accuracy: 0.9703 - iou_coef: 0.3569 - dice_coef: 0.3751 - val_loss: 0.3631 - val_accuracy: 0.8675 - val_iou_coef: 0.3554 - val_dice_coef: 0.3949
# Epoch 75/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9702 - iou_coef: 0.3641 - dice_coef: 0.3823
# Epoch 00075: val_loss did not improve from 0.18610
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 9.999999682655225e-21.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0834 - accuracy: 0.9702 - iou_coef: 0.3641 - dice_coef: 0.3823 - val_loss: 0.4008 - val_accuracy: 0.8596 - val_iou_coef: 0.3542 - val_dice_coef: 0.3957
# Epoch 76/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9702 - iou_coef: 0.3646 - dice_coef: 0.3828
# Epoch 00076: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.0826 - accuracy: 0.9702 - iou_coef: 0.3645 - dice_coef: 0.3827 - val_loss: 0.3799 - val_accuracy: 0.8654 - val_iou_coef: 0.3757 - val_dice_coef: 0.4129
# Epoch 77/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9701 - iou_coef: 0.3586 - dice_coef: 0.3767
# Epoch 00077: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0844 - accuracy: 0.9701 - iou_coef: 0.3584 - dice_coef: 0.3765 - val_loss: 0.3491 - val_accuracy: 0.8726 - val_iou_coef: 0.4040 - val_dice_coef: 0.4457
# Epoch 78/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9719 - iou_coef: 0.3611 - dice_coef: 0.3791
# Epoch 00078: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0793 - accuracy: 0.9719 - iou_coef: 0.3613 - dice_coef: 0.3793 - val_loss: 0.4151 - val_accuracy: 0.8568 - val_iou_coef: 0.3567 - val_dice_coef: 0.4009
# Epoch 79/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9708 - iou_coef: 0.3651 - dice_coef: 0.3827
# Epoch 00079: val_loss did not improve from 0.18610
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 9.999999682655225e-22.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0817 - accuracy: 0.9708 - iou_coef: 0.3652 - dice_coef: 0.3828 - val_loss: 0.3169 - val_accuracy: 0.8860 - val_iou_coef: 0.4062 - val_dice_coef: 0.4470
# Epoch 80/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9702 - iou_coef: 0.3586 - dice_coef: 0.3769
# Epoch 00080: val_loss did not improve from 0.18610
# 579/579 [==============================] - 572s 988ms/step - loss: 0.0830 - accuracy: 0.9702 - iou_coef: 0.3585 - dice_coef: 0.3768 - val_loss: 0.4037 - val_accuracy: 0.8565 - val_iou_coef: 0.3804 - val_dice_coef: 0.4232
# Epoch 81/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9706 - iou_coef: 0.3601 - dice_coef: 0.3784
# Epoch 00081: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0824 - accuracy: 0.9706 - iou_coef: 0.3599 - dice_coef: 0.3782 - val_loss: 0.3409 - val_accuracy: 0.8726 - val_iou_coef: 0.4121 - val_dice_coef: 0.4591
# Epoch 82/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9709 - iou_coef: 0.3642 - dice_coef: 0.3823
# Epoch 00082: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0817 - accuracy: 0.9709 - iou_coef: 0.3644 - dice_coef: 0.3825 - val_loss: 0.4318 - val_accuracy: 0.8586 - val_iou_coef: 0.3672 - val_dice_coef: 0.4068
# Epoch 83/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9705 - iou_coef: 0.3600 - dice_coef: 0.3779
# Epoch 00083: val_loss did not improve from 0.18610
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 9.999999682655225e-23.
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0824 - accuracy: 0.9706 - iou_coef: 0.3598 - dice_coef: 0.3777 - val_loss: 0.3965 - val_accuracy: 0.8636 - val_iou_coef: 0.3846 - val_dice_coef: 0.4278
# Epoch 84/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9702 - iou_coef: 0.3629 - dice_coef: 0.3813
# Epoch 00084: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0838 - accuracy: 0.9701 - iou_coef: 0.3630 - dice_coef: 0.3815 - val_loss: 0.3538 - val_accuracy: 0.8710 - val_iou_coef: 0.3831 - val_dice_coef: 0.4258
# Epoch 85/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9704 - iou_coef: 0.3572 - dice_coef: 0.3752
# Epoch 00085: val_loss did not improve from 0.18610
# 579/579 [==============================] - 575s 992ms/step - loss: 0.0831 - accuracy: 0.9704 - iou_coef: 0.3576 - dice_coef: 0.3755 - val_loss: 0.4044 - val_accuracy: 0.8583 - val_iou_coef: 0.3761 - val_dice_coef: 0.4197
# Epoch 86/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9706 - iou_coef: 0.3591 - dice_coef: 0.3770
# Epoch 00086: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0818 - accuracy: 0.9706 - iou_coef: 0.3593 - dice_coef: 0.3772 - val_loss: 0.3776 - val_accuracy: 0.8710 - val_iou_coef: 0.3723 - val_dice_coef: 0.4102
# Epoch 87/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9709 - iou_coef: 0.3648 - dice_coef: 0.3831
# Epoch 00087: val_loss did not improve from 0.18610
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 9.999999682655227e-24.
# 579/579 [==============================] - 573s 991ms/step - loss: 0.0819 - accuracy: 0.9710 - iou_coef: 0.3647 - dice_coef: 0.3830 - val_loss: 0.4419 - val_accuracy: 0.8425 - val_iou_coef: 0.3911 - val_dice_coef: 0.4340
# Epoch 88/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0814 - accuracy: 0.9710 - iou_coef: 0.3605 - dice_coef: 0.3786
# Epoch 00088: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0813 - accuracy: 0.9710 - iou_coef: 0.3605 - dice_coef: 0.3787 - val_loss: 0.3051 - val_accuracy: 0.8939 - val_iou_coef: 0.3716 - val_dice_coef: 0.4116
# Epoch 89/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9702 - iou_coef: 0.3598 - dice_coef: 0.3774
# Epoch 00089: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0834 - accuracy: 0.9702 - iou_coef: 0.3597 - dice_coef: 0.3773 - val_loss: 0.3527 - val_accuracy: 0.8664 - val_iou_coef: 0.3848 - val_dice_coef: 0.4283
# Epoch 90/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9710 - iou_coef: 0.3612 - dice_coef: 0.3792
# Epoch 00090: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 989ms/step - loss: 0.0817 - accuracy: 0.9710 - iou_coef: 0.3612 - dice_coef: 0.3792 - val_loss: 0.4045 - val_accuracy: 0.8565 - val_iou_coef: 0.4113 - val_dice_coef: 0.4530
# Epoch 91/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9699 - iou_coef: 0.3617 - dice_coef: 0.3801
# Epoch 00091: val_loss did not improve from 0.18610
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 9.999999998199588e-25.
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0836 - accuracy: 0.9700 - iou_coef: 0.3616 - dice_coef: 0.3800 - val_loss: 0.4065 - val_accuracy: 0.8576 - val_iou_coef: 0.3835 - val_dice_coef: 0.4304
# Epoch 92/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9710 - iou_coef: 0.3617 - dice_coef: 0.3798
# Epoch 00092: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0821 - accuracy: 0.9710 - iou_coef: 0.3618 - dice_coef: 0.3800 - val_loss: 0.4377 - val_accuracy: 0.8627 - val_iou_coef: 0.4045 - val_dice_coef: 0.4422
# Epoch 93/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0816 - accuracy: 0.9712 - iou_coef: 0.3580 - dice_coef: 0.3754
# Epoch 00093: val_loss did not improve from 0.18610
# 579/579 [==============================] - 573s 990ms/step - loss: 0.0815 - accuracy: 0.9712 - iou_coef: 0.3578 - dice_coef: 0.3752 - val_loss: 0.3413 - val_accuracy: 0.8776 - val_iou_coef: 0.3715 - val_dice_coef: 0.4121
# Epoch 94/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9699 - iou_coef: 0.3628 - dice_coef: 0.3809
# Epoch 00094: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0849 - accuracy: 0.9699 - iou_coef: 0.3627 - dice_coef: 0.3809 - val_loss: 0.4579 - val_accuracy: 0.8439 - val_iou_coef: 0.3834 - val_dice_coef: 0.4280
# Epoch 95/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9718 - iou_coef: 0.3618 - dice_coef: 0.3800
# Epoch 00095: val_loss did not improve from 0.18610
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.0000000195414814e-25.
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0804 - accuracy: 0.9719 - iou_coef: 0.3619 - dice_coef: 0.3801 - val_loss: 0.3762 - val_accuracy: 0.8699 - val_iou_coef: 0.4060 - val_dice_coef: 0.4474
# Epoch 96/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9704 - iou_coef: 0.3598 - dice_coef: 0.3782
# Epoch 00096: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 991ms/step - loss: 0.0829 - accuracy: 0.9704 - iou_coef: 0.3604 - dice_coef: 0.3787 - val_loss: 0.3767 - val_accuracy: 0.8680 - val_iou_coef: 0.3948 - val_dice_coef: 0.4377
# Epoch 97/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9706 - iou_coef: 0.3627 - dice_coef: 0.3804
# Epoch 00097: val_loss did not improve from 0.18610
# 579/579 [==============================] - 574s 992ms/step - loss: 0.0820 - accuracy: 0.9706 - iou_coef: 0.3629 - dice_coef: 0.3806 - val_loss: 0.3393 - val_accuracy: 0.8820 - val_iou_coef: 0.4273 - val_dice_coef: 0.4678
# Epoch 98/500
# 239/579 [===========>..................] - ETA: 5:30 - loss: 0.0866 - accuracy: 0.9703 - iou_coef: 0.3571 - dice_coef: 0.3750
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-7e86d73ad535> in <module>
#      14                     epochs = epoch,
#      15                     callbacks = callbacks,
# ---> 16                     verbose = 1,
#      17                     )
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     266           model._backwards(tape, scaled_total_loss)
#     267         else:
# --> 268           grads = tape.gradient(scaled_total_loss, trainable_weights)
#     269           if isinstance(model.optimizer,
#     270                         loss_scale_optimizer.LossScaleOptimizer):
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1012         output_gradients=output_gradients,
#    1013         sources_raw=flat_sources_raw,
# -> 1014         unconnected_gradients=unconnected_gradients)
#    1015
#    1016     if not self._persistent:
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      74       output_gradients,
#      75       sources_raw,
# ---> 76       compat.as_str(unconnected_gradients.value))
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\eager\backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     136     return [None] * num_inputs
#     137
# --> 138   return grad_fn(mock_op, *out_grads)
#     139
#     140
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\ops\math_grad.py in _MulGrad(op, grad)
#    1167     if skip_input_indices is not None and 1 in skip_input_indices and _IsScalar(
#    1168         y):
# -> 1169       return gen_math_ops.mul(grad, math_ops.conj(y)), None
#    1170   except AttributeError:
#    1171     # No gradient skipping, so do the full gradient computation
#
# ~\Anaconda3\envs\tfdl02\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mul(x, y, name)
#    6683       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    6684         _ctx._context_handle, _ctx._thread_local_data.device_name, "Mul",
# -> 6685         name, _ctx._post_execution_callbacks, x, y)
#    6686       return _result
#    6687     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model
