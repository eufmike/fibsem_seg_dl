# %% [markdown]
# # Training Model
# Keras on Tensorflow
#
# trained from  /2020_01_23/model_2020_01_23_17_15.h5

# %%
import os, sys
import cv2
import numpy as np
import uuid
import tensorflow as tf
from skimage.io import imread, imsave, imshow
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
from imutils import paths
import itertools
import json
from pprint import pprint

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from core.imageprep import dir_checker, random_crop, crop_generator, random_crop_batch
from core.models import UNet
from core.metrics import iou_coef, dice_coef

from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau
from datetime import datetime

from IPython import get_ipython
# %load_ext autoreload
get_ipython().run_line_magic('load_ext', 'autoreload')
# %autoreload 2
get_ipython().run_line_magic('autoreload', '2')
# %load_ext tensorboard
get_ipython().run_line_magic('load_ext', 'tensorboard')

# %%
from packaging import version
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.0.0

# %%
sys.executable
# Out:
# 'C:\\Users\\wucci_admin\\Anaconda3\\envs\\tfdl02\\python.exe'

# %% [markdown]
#  ## Load Training Dataset

# %%
# load image
print("Load Images...")
# on mac
# path = "/Volumes/LaCie_DataStorage/PerlmutterData/"

# on Window PC 
path = os.path.join('D:', 'PerlmutterData')

# input set
crop_input_set = '2020_01_23_09_51_20x'
# crop_input_set = '2019_12_10_15_33_5x' # small training set

imginput = os.path.join('dl_seg_project_raw', 'data_crop', crop_input_set,)
imgpath = os.path.join(path, imginput)

print(imgpath)

img_dir = os.path.join(imgpath, 'images')
label_dir = os.path.join(imgpath, 'labels')
print(img_dir)
print(label_dir)

# check if the output folder exist. If not, create a folder
dir_checker('logs', path)
path_logs = os.path.join(path, 'logs')
dir_checker('fit', path_logs)
dir_checker('model', path_logs)
dir_checker('pars', path_logs)
# Out:
# Load Images...
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\labels
# logs exists in D:PerlmutterData
# fit exists in D:PerlmutterData\logs
# model exists in D:PerlmutterData\logs
# pars exists in D:PerlmutterData\logs

# %% [markdown]
#  Print the first file name.

# %%
imgpath_all = list(paths.list_images(imgpath))
print(imgpath_all[0])
# Out:
# D:PerlmutterData\dl_seg_project_raw\data_crop\2020_01_23_09_51_20x\images\nucleus\0001.tif

# %% [markdown]
#  ## Create Image Datagenerator
#  1. create only one datagen
#  2. specify valiation split in datagen argument
#  3. add split data when calling `datagen.flow_from_directory`

# %%
timestamp = datetime.now().strftime("%Y_%m_%d_%H_%M")
date =  datetime.now().strftime("%Y_%m_%d")
seed = 102
batch_size = 16
epoch = 500
validation_steps = 20
validation_split = 0.3
training_sample_size = len(imgpath_all)
IMG_HEIGHT = None
IMG_WIDTH = None
classes = ['cell_membrane', 'nucleus', 'autophagosome']
inputclass = [classes[1]]
learning_rate = 1e-4
loss = "binary_crossentropy"
metrics = ['accuracy', iou_coef, dice_coef]

metrics_name = []
for f in metrics:
    if callable(f):
        metrics_name.append(f.__name__)
    else:
        metrics_name.append(f)

# %%
# create arguments for data generator
data_gen_img_args = dict(
                # featurewise_center = True,
                # featurewise_std_normalization = True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                rescale=1.0/255.0,
                )

data_gen_label_args = dict(
                # featurewise_center=True,
                # featurewise_std_normalization=True,
                horizontal_flip = True,
                vertical_flip = True,
                rotation_range = 90.,
                width_shift_range = 0.1,
                height_shift_range = 0.1,
                shear_range = 0.07,
                zoom_range = 0.2,
                validation_split = validation_split, # <- specify validation_split ratio
                # fill_mode='constant',
                # cval=0.,
                # rescale=1.0/255.0,
                rescale=1.0/255.0,
                )

# create parameter
pars = dict(
                # basic information
                timestamp = timestamp,
                date = date,
                seed = seed,
                batch_size = batch_size,
                
                # Data generator
                crop_input_set = crop_input_set,
                validation_steps = validation_steps,
                validation_split = validation_split,
                training_sample_size = training_sample_size,
                
                # training class
                classes = classes,
                inputclass = inputclass,
    
                # add datagen args
                data_gen_img_args = data_gen_img_args,
                data_gen_label_args = data_gen_label_args,
                
                # Build model
                IMG_HEIGHT = IMG_HEIGHT,
                IMG_WIDTH = IMG_WIDTH,
                epoch = epoch, 
                loss = loss,
                metrics_name = metrics_name,
                learning_rate = learning_rate,
                )

# save parameter
path_pars = os.path.join(path_logs, 'pars')
dir_checker(inputclass[0], path_pars)
dir_checker(date, os.path.join(path_pars, inputclass[0]))

pprint(pars)
# Out:
# nucleus exists in D:PerlmutterData\logs\pars
# 2020_01_24 does not exist in D:PerlmutterData\logs\pars\nucleus
# {'IMG_HEIGHT': None,
#  'IMG_WIDTH': None,
#  'batch_size': 16,
#  'classes': ['cell_membrane', 'nucleus', 'autophagosome'],
#  'crop_input_set': '2020_01_23_09_51_20x',
#  'data_gen_img_args': {'height_shift_range': 0.1,
#                        'horizontal_flip': True,
#                        'rescale': 0.00392156862745098,
#                        'rotation_range': 90.0,
#                        'shear_range': 0.07,
#                        'validation_split': 0.3,
#                        'vertical_flip': True,
#                        'width_shift_range': 0.1,
#                        'zoom_range': 0.2},
#  'data_gen_label_args': {'height_shift_range': 0.1,
#                          'horizontal_flip': True,
#                          'rescale': 0.00392156862745098,
#                          'rotation_range': 90.0,
#                          'shear_range': 0.07,
#                          'validation_split': 0.3,
#                          'vertical_flip': True,
#                          'width_shift_range': 0.1,
#                          'zoom_range': 0.2},
#  'date': '2020_01_24',
#  'epoch': 500,
#  'inputclass': ['nucleus'],
#  'learning_rate': 0.0001,
#  'loss': 'binary_crossentropy',
#  'metrics_name': ['accuracy', 'iou_coef', 'dice_coef'],
#  'seed': 102,
#  'timestamp': '2020_01_24_16_02',
#  'training_sample_size': 13240,
#  'validation_split': 0.3,
#  'validation_steps': 20}

# %%
par_file_dir = os.path.join(path_pars, inputclass[0], date, 'pars_' + timestamp + '.json')
print(par_file_dir)

with open(par_file_dir, 'w') as outfile:
    json.dump(pars, outfile, indent=4)
# Out:
# D:PerlmutterData\logs\pars\nucleus\2020_01_24\pars_2020_01_24_16_02.json

# %%
# create generator
image_datagen = ImageDataGenerator(**data_gen_img_args)
label_datagen = ImageDataGenerator(**data_gen_label_args)

# %%
# load images into generator
train_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training', # <- define subset as 'training'
    seed=seed)

train_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='training',
    seed=seed)

valid_image_generator = image_datagen.flow_from_directory(
    img_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation', # <- define subset as 'validation'
    seed=seed)

valid_label_generator = label_datagen.flow_from_directory(
    label_dir,
    class_mode=None,
    classes=inputclass,
    color_mode='grayscale',
    batch_size=batch_size,
    subset='validation',
    seed=seed)
# Out:
# Found 4634 images belonging to 1 classes.
# Found 4634 images belonging to 1 classes.
# Found 1986 images belonging to 1 classes.
# Found 1986 images belonging to 1 classes.

# %%
# merge image and label generator
def combine_generator(gen1, gen2):
    while True:
        yield(gen1.next(), gen2.next()) 
train_generator = combine_generator(train_image_generator, train_label_generator)
valid_generator = combine_generator(valid_image_generator, valid_label_generator)

# %%
'''
train_generator = zip(train_image_generator, train_label_generator)
valid_generator = zip(valid_image_generator, valid_label_generator)
'''
# Out:
# '\ntrain_generator = zip(train_image_generator, train_label_generator)\nvalid_generator = zip(valid_image_generator, valid_label_generator)\n'

# %% [markdown]
#  ## Training

# %%
print("Start training...")
# Out:
# Start training...

# %% [markdown]
#  ### Define Callbacks

# %%
# checkpoint
modelfilename = 'model_' + timestamp + '.h5'
dir_checker(inputclass[0], os.path.join(path_logs, 'model'))
dir_checker(date, os.path.join(path_logs, 'model', inputclass[0]))
modelfile_path = os.path.join(path_logs, 'model', inputclass[0], date, modelfilename)

checkpointer = ModelCheckpoint(filepath = modelfile_path, 
                               monitor = 'val_loss', 
                               mode = 'min', 
                               verbose = 1, 
                               save_best_only = True)

# early stopping 
early_stopping = EarlyStopping(monitor='val_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4)

# learning rate adjustment
reduceLR = ReduceLROnPlateau(monitor='val_loss',
                    factor=0.1,
                    patience=4,
                    verbose=1,
                    min_delta=1e-4)

# tensorboard
from tensorflow.summary import create_file_writer

dir_checker(inputclass[0], os.path.join(path_logs, 'fit'))
dir_checker(date, os.path.join(path_logs, 'fit', inputclass[0]))
logdir = os.path.join(path_logs, 'fit', inputclass[0], date, timestamp)

file_writer = create_file_writer(logdir + "/metrics")
file_writer.set_as_default()

metrics = ['accuracy', iou_coef, dice_coef]


tensorboard_callback = TensorBoard(log_dir = logdir, 
                                   profile_batch = 0, 
                                   update_freq= 500,
                                   histogram_freq = 1
                                   )

# compile callbacks
# callbacks = [checkpointer, tensorboard_callback, early_stopping, reduceLR]
callbacks = [checkpointer, tensorboard_callback, reduceLR]
# Out:
# nucleus exists in D:PerlmutterData\logs\model
# 2020_01_24 does not exist in D:PerlmutterData\logs\model\nucleus
# nucleus exists in D:PerlmutterData\logs\fit
# 2020_01_24 does not exist in D:PerlmutterData\logs\fit\nucleus

# %% [markdown]
#  ### Setup the model

# %%
# calculate steps_per_epoch
steps_per_epoch = training_sample_size * (1 - validation_split) // batch_size
print("Steps per epoch: {}".format(steps_per_epoch))
# Out:
# Steps per epoch: 579.0

# %%
print(logdir)
# Out:
# D:PerlmutterData\logs\fit\nucleus\2020_01_24\2020_01_24_16_02

# %%
'''
# prepare the model
unetmodel = UNet(shape = (IMG_HEIGHT, IMG_WIDTH), 
                 lr = learning_rate, 
                 loss = loss,
                 metrics = metrics,
                )

# train the model
unetmodel.fit_generator(
                    generator = train_generator, 
                    validation_data = valid_generator,
                    validation_steps = validation_steps,
                    steps_per_epoch = steps_per_epoch,
                    epochs = epoch,  
                    callbacks = callbacks,
                    verbose = 1, 
                    )
'''
# Out:
# '\n# prepare the model\nunetmodel = UNet(shape = (IMG_HEIGHT, IMG_WIDTH), \n                 lr = learning_rate, \n                 loss = loss,\n                 metrics = metrics,\n                )\n\n# train the model\nunetmodel.fit_generator(\n                    generator = train_generator, \n                    validation_data = valid_generator,\n                    validation_steps = validation_steps,\n                    steps_per_epoch = steps_per_epoch,\n                    epochs = epoch,  \n                    callbacks = callbacks,\n                    verbose = 1, \n                    )\n'

# %%
from tensorflow.keras.models import load_model

path_model = os.path.join(os.path.join(path_logs, 'model', inputclass[0]), '2020_01_23', 'model_2020_01_23_17_15.h5')

unetmodel = UNet(shape = (IMG_HEIGHT, IMG_WIDTH), 
                 lr =1e-6, 
                 loss = loss,
                 metrics = metrics,
                )

unetmodel.load_weights(path_model)

unetmodel.fit_generator(
                    generator = train_generator, 
                    validation_data = valid_generator,
                    validation_steps = validation_steps,
                    steps_per_epoch = steps_per_epoch,
                    epochs = epoch,  
                    callbacks = callbacks,
                    verbose = 1, 
                    )
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 1 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 5 1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 5 2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 5 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, None, None, 1 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 5 2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 5 4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 5 2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 5 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 2 524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 2 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 1 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, None, None, 1 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1513 - accuracy: 0.9549 - iou_coef: 0.3066 - dice_coef: 0.3340
# Epoch 00001: val_loss improved from inf to 0.34034, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_24\model_2020_01_24_16_02.h5
# 579/579 [==============================] - 579s 1s/step - loss: 0.1514 - accuracy: 0.9549 - iou_coef: 0.3068 - dice_coef: 0.3342 - val_loss: 0.3403 - val_accuracy: 0.9066 - val_iou_coef: 0.3989 - val_dice_coef: 0.4340
# Epoch 2/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.
500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9604 - iou_coef: 0.3233 - dice_coef: 0.3447
# Epoch 00070: val_loss did not improve from 0.24560
# 579/579 [==============================] - 575s 994ms/step - loss: 0.1170 - accuracy: 0.9604 - iou_coef: 0.3238 - dice_coef: 0.3452 - val_loss: 0.3118 - val_accuracy: 0.9035 - val_iou_coef: 0.3810 - val_dice_coef: 0.4204
# Epoch 71/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1191 - accuracy: 0.9597 - iou_coef: 0.3224 - dice_coef: 0.3440
# Epoch 00071: val_loss did not improve from 0.24560
# 579/579 [==============================] - 575s 994ms/step - loss: 0.1190 - accuracy: 0.9598 - iou_coef: 0.3226 - dice_coef: 0.3442 - val_loss: 0.3238 - val_accuracy: 0.9007 - val_iou_coef: 0.3706 - val_dice_coef: 0.4116
# Epoch 72/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1174 - accuracy: 0.9608 - iou_coef: 0.3249 - dice_coef: 0.3465
# Epoch 00072: val_loss did not improve from 0.24560
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 9.999999682655227e-24.
# 579/579 [==============================] - 576s 994ms/step - loss: 0.1176 - accuracy: 0.9608 - iou_coef: 0.3252 - dice_coef: 0.3468 - val_loss: 0.4232 - val_accuracy: 0.8759 - val_iou_coef: 0.3717 - val_dice_coef: 0.4121
# Epoch 73/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1157 - accuracy: 0.9614 - iou_coef: 0.3265 - dice_coef: 0.3482
# Epoch 00073: val_loss did not improve from 0.24560
# 579/579 [==============================] - 575s 993ms/step - loss: 0.1156 - accuracy: 0.9615 - iou_coef: 0.3267 - dice_coef: 0.3484 - val_loss: 0.3722 - val_accuracy: 0.8848 - val_iou_coef: 0.4007 - val_dice_coef: 0.4447
# Epoch 74/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9589 - iou_coef: 0.3213 - dice_coef: 0.3429
# Epoch 00074: val_loss did not improve from 0.24560
# 579/579 [==============================] - 576s 994ms/step - loss: 0.1216 - accuracy: 0.9590 - iou_coef: 0.3215 - dice_coef: 0.3431 - val_loss: 0.4109 - val_accuracy: 0.8778 - val_iou_coef: 0.4016 - val_dice_coef: 0.4389
# Epoch 75/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9611 - iou_coef: 0.3277 - dice_coef: 0.3495
# Epoch 00075: val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 991ms/step - loss: 0.1171 - accuracy: 0.9612 - iou_coef: 0.3275 - dice_coef: 0.3492 - val_loss: 0.3273 - val_accuracy: 0.9005 - val_iou_coef: 0.3915 - val_dice_coef: 0.4344
# Epoch 76/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9599 - iou_coef: 0.3275 - dice_coef: 0.3492
# Epoch 00076: val_loss did not improve from 0.24560
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 9.999999998199588e-25.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1191 - accuracy: 0.9599 - iou_coef: 0.3274 - dice_coef: 0.3491 - val_loss: 0.2998 - val_accuracy: 0.9100 - val_iou_coef: 0.3762 - val_dice_coef: 0.4127
# Epoch 77/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9592 - iou_coef: 0.3229 - dice_coef: 0.3446
# Epoch 00077: val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1214 - accuracy: 0.9593 - iou_coef: 0.3228 - dice_coef: 0.3445 - val_loss: 0.4013 - val_accuracy: 0.8984 - val_iou_coef: 0.3881 - val_dice_coef: 0.4242
# Epoch 78/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9624 - iou_coef: 0.3255 - dice_coef: 0.3471
# Epoch 00078: val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1137 - accuracy: 0.9623 - iou_coef: 0.3256 - dice_coef: 0.3471 - val_loss: 0.3357 - val_accuracy: 0.8973 - val_iou_coef: 0.4095 - val_dice_coef: 0.4490
# Epoch 79/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9599 - iou_coef: 0.3256 - dice_coef: 0.3470
# Epoch 00079: val_loss did not improve from 0.24560
# 579/579 [==============================] - 574s 992ms/step - loss: 0.
val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1183 - accuracy: 0.9604 - iou_coef: 0.3249 - dice_coef: 0.3464 - val_loss: 0.3400 - val_accuracy: 0.8979 - val_iou_coef: 0.3897 - val_dice_coef: 0.4285
# Epoch 90/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9612 - iou_coef: 0.3229 - dice_coef: 0.3444
# Epoch 00090: val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1157 - accuracy: 0.9611 - iou_coef: 0.3227 - dice_coef: 0.3442 - val_loss: 0.3980 - val_accuracy: 0.8779 - val_iou_coef: 0.3900 - val_dice_coef: 0.4264
# Epoch 91/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9600 - iou_coef: 0.3254 - dice_coef: 0.3473
# Epoch 00091: val_loss did not improve from 0.24560
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1203 - accuracy: 0.9601 - iou_coef: 0.3253 - dice_coef: 0.3471 - val_loss: 0.3261 - val_accuracy: 0.8961 - val_iou_coef: 0.3668 - val_dice_coef: 0.4017
# Epoch 92/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9606 - iou_coef: 0.3256 - dice_coef: 0.3471
# Epoch 00092: val_loss did not improve from 0.24560
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.0000000272452012e-28.
# 579/579 [==============================] - 574s 992ms/step - loss: 0.1169 - accuracy: 0.9606 - iou_coef: 0.3254 - dice_coef: 0.3469 - val_loss: 0.3817 - val_accuracy: 0.8829 - val_iou_coef: 0.4006 - val_dice_coef: 0.4411
# Epoch 93/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9607 - iou_coef: 0.3249 - dice_coef: 0.3463
# Epoch 00093: val_loss did not improve from 0.24560
# 579/579 [==============================] - 574s 992ms/step - loss: 0.1178 - accuracy: 0.9607 - iou_coef: 0.3250 - dice_coef: 0.3464 - val_loss: 0.3260 - val_accuracy: 0.8977 - val_iou_coef: 0.3571 - val_dice_coef: 0.3962
# Epoch 94/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9604 - iou_coef: 0.3237 - dice_coef: 0.3456
# Epoch 00094: val_loss improved from 0.24560 to 0.23911, saving model to D:PerlmutterData\logs\model\nucleus\2020_01_24\model_2020_01_24_16_02.h5
# 579/579 [==============================] - 577s 997ms/step - loss: 0.1191 - accuracy: 0.9603 - iou_coef: 0.3238 - dice_coef: 0.3457 - val_loss: 0.2391 - val_accuracy: 0.9254 - val_iou_coef: 0.4434 - val_dice_coef: 0.4842
# Epoch 95/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9605 - iou_coef: 0.3250 - dice_coef: 0.3467
# Epoch 00095: val_loss did not improve from 0.23911
# 579/579 [==============================] - 576s 994ms/step - loss: 0.1180 - accuracy: 0.9604 - iou_coef: 0.3248 - dice_coef: 0.3465 - val_loss: 0.3592 - val_accuracy: 0.8905 - val_iou_coef: 0.3794 - val_dice_coef: 0.4191
# Epoch 96/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9606 - iou_coef: 0.3251 - dice_coef: 0.3470
# Epoch 00096: val_loss did not improve from 0.23911
# 579/579 [==============================] - 576s 994ms/step - loss: 0.1179 - accuracy: 0.9605 - iou_coef: 0.3249 - dice_coef: 0.3469 - val_loss: 0.2940 - val_accuracy: 0.9120 - val_iou_coef: 0.4014 - val_dice_coef: 0.4408
# Epoch 97/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9604 - iou_coef: 0.3251 - dice_coef: 0.3468
# Epoch 00097: val_loss did not improve from 0.23911
# 579/579 [==============================] - 575s 993ms/step - loss: 0.1181 - accuracy: 0.9603 - iou_coef: 0.3249 - dice_coef: 0.3466 - val_loss: 0.3812 - val_accuracy: 0.8845 - val_iou_coef: 0.3771 - val_dice_coef: 0.4132
# Epoch 98/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1194 - accuracy: 0.9600 - iou_coef: 0.3244 - dice_coef: 0.3460
# Epoch 00098: val_loss did not improve from 0.23911
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 1.0000000031710769e-29.
# 579/579 [==============================] - 575s 993ms/step - loss: 0.1194 - accuracy: 0.9600 - iou_coef: 0.3246 - dice_coef: 0.3462 - val_loss: 0.3633 - val_accuracy: 0.8897 - val_iou_coef: 0.3999 - val_dice_coef: 0.4390
# Epoch 99/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9597 - iou_coef: 0.3257 - dice_coef: 0.3471
# Epoch 00099: val_loss did not improve from 0.23911
# 579/579 [==============================] - 576s 994ms/step - loss: 0.1191 - accuracy: 0.9597 - iou_coef: 0.3252 - dice_coef: 0.3466 - val_loss: 0.3521 - val_accuracy: 0.8944 - val_iou_coef: 0.3811 - val_dice_coef: 0.4207
# Epoch 100/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9611 - iou_coef: 0.3258 - dice_coef: 0.3476
# Epoch 00100: val_loss did not improve from 0.23911
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1170 - accuracy: 0.9611 - iou_coef: 0.3260 - dice_coef: 0.3479 - val_loss: 0.3660 - val_accuracy: 0.8890 - val_iou_coef: 0.4094 - val_dice_coef: 0.4501
# Epoch 101/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9609 - iou_coef: 0.3228 - dice_coef: 0.3446
# Epoch 00101: val_loss did not improve from 0.23911
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1168 - accuracy: 0.9610 - iou_coef: 0.3227 - dice_coef: 0.3445 - val_loss: 0.3770 - val_accuracy: 0.8873 - val_iou_coef: 0.3572 - val_dice_coef: 0.3967
# Epoch 102/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9602 - iou_coef: 0.3265 - dice_coef: 0.3480
# Epoch 00102: val_loss did not improve from 0.23911
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 1.0000000031710769e-30.
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1182 - accuracy: 0.9602 - iou_coef: 0.3265 - dice_coef: 0.3480 - val_loss: 0.3451 - val_accuracy: 0.9020 - val_iou_coef: 0.3724 - val_dice_coef: 0.4098
# Epoch 103/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1235 - accuracy: 0.9583 - iou_coef: 0.3256 - dice_coef: 0.3474
# Epoch 00103: val_loss did not improve from 0.23911
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1233 - accuracy: 0.9584 - iou_coef: 0.3255 - dice_coef: 0.3473 - val_loss: 0.3474 - val_accuracy: 0.8950 - val_iou_coef: 0.4248 - val_dice_coef: 0.4658
# Epoch 104/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9628 - iou_coef: 0.3245 - dice_coef: 0.3464
# Epoch 00104: val_loss did not improve from 0.23911
# 579/579 [==============================] - 576s 995ms/step - loss: 0.1117 - accuracy: 0.9629 - iou_coef: 0.3247 - dice_coef: 0.3466 - val_loss: 0.3772 - val_accuracy: 0.8824 - val_iou_coef: 0.3891 - val_dice_coef: 0.4302
# Epoch 105/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9605 - iou_coef: 0.3285 - dice_coef: 0.3502
# Epoch 00105: val_loss did not improve from 0.23911
# 579/579 [==============================] - 577s 996ms/step - loss: 0.1177 - accuracy: 0.9605 - iou_coef: 0.3286 - dice_coef: 0.3503 - val_loss: 0.3828 - val_accuracy: 0.8909 - val_iou_coef: 0.3580 - val_dice_coef: 0.3942
# Epoch 106/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9598 - iou_coef: 0.3227 - dice_coef: 0.3445
# Epoch 00106: val_loss did not improve from 0.23911
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 1.000000003171077e-31.
# 579/579 [==============================] - 576s 996ms/step - loss: 0.1192 - accuracy: 0.9599 - iou_coef: 0.3228 - dice_coef: 0.3446 - val_loss: 0.3314 - val_accuracy: 0.8960 - val_iou_coef: 0.3916 - val_dice_coef: 0.4292
# Epoch 107/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9612 - iou_coef: 0.3224 - dice_coef: 0.3439
# Epoch 00107: val_loss did not improve from 0.23911
# 579/579 [==============================] - 577s 997ms/step - loss: 0.1159 - accuracy: 0.9613 - iou_coef: 0.3224 - dice_coef: 0.3438 - val_loss: 0.3321 - val_accuracy: 0.8983 - val_iou_coef: 0.3973 - val_dice_coef: 0.4386
# Epoch 108/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9599 - iou_coef: 0.3258 - dice_coef: 0.3474
# Epoch 00108: val_loss did not improve from 0.23911
# 579/579 [==============================] - 577s 996ms/step - loss: 0.1191 - accuracy: 0.9599 - iou_coef: 0.3259 - dice_coef: 0.3474 - val_loss: 0.3051 - val_accuracy: 0.9086 - val_iou_coef: 0.3938 - val_dice_coef: 0.4334
# Epoch 109/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9610 - iou_coef: 0.3262 - dice_coef: 0.3482
# Epoch 00109: val_loss did not improve from 0.23911
# 579/579 [==============================] - 575s 993ms/step - loss: 0.1172 - accuracy: 0.9610 - iou_coef: 0.3261 - dice_coef: 0.3481 - val_loss: 0.3435 - val_accuracy: 0.8952 - val_iou_coef: 0.3991 - val_dice_coef: 0.4335
# Epoch 110/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1191 - accuracy: 0.9602 - iou_coef: 0.3246 - dice_coef: 0.3464
# Epoch 00110: val_loss did not improve from 0.23911
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 9.999999796611899e-33.
# 579/579 [==============================] - 576s 995ms/step - loss: 0.1197 - accuracy: 0.9601 - iou_coef: 0.3246 - dice_coef: 0.3464 - val_loss: 0.4019 - val_accuracy: 0.8825 - val_iou_coef: 0.3719 - val_dice_coef: 0.4096
# Epoch 111/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1190 - accuracy: 0.9597 - iou_coef: 0.3252 - dice_coef: 0.3470
# Epoch 00111: val_loss did not improve from 0.23911
# 579/579 [==============================] - 575s 993ms/step - loss: 0.1189 - accuracy: 0.9598 - iou_coef: 0.3253 - dice_coef: 0.3471 - val_loss: 0.2962 - val_accuracy: 0.9053 - val_iou_coef: 0.3671 - val_dice_coef: 0.4096
# Epoch 112/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1197 - accuracy: 0.9602 - iou_coef: 0.3241 - dice_coef: 0.3459
# Epoch 00112: val_loss did not improve from 0.23911
# 579/579 [==============================] - 574s 992ms/step - loss: 0.1195 - accuracy: 0.9603 - iou_coef: 0.3242 - dice_coef: 0.3459 - val_loss: 0.3356 - val_accuracy: 0.8968 - val_iou_coef: 0.3623 - val_dice_coef: 0.3987
# Epoch 113/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9609 - iou_coef: 0.3238 - dice_coef: 0.3451
# Epoch 00113: val_loss did not improve from 0.23911
# 579/579 [==============================] - 574s 991ms/step - loss: 0.1157 - accuracy: 0.9610 - iou_coef: 0.3237 - dice_coef: 0.3451 - val_loss: 0.2811 - val_accuracy: 0.9118 - val_iou_coef: 0.3984 - val_dice_coef: 0.4397
# Epoch 114/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.9607 - iou_coef: 0.3273 - dice_coef: 0.3496
# Epoch 00114: val_loss did not improve from 0.23911
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 9.999999502738312e-34.
# 579/579 [==============================] - 573s 989ms/step - loss: 0.1185 - accuracy: 0.9608 - iou_coef: 0.3274 - dice_coef: 0.3497 - val_loss: 0.3499 - val_accuracy: 0.8893 - val_iou_coef: 0.3766 - val_dice_coef: 0.4150
# Epoch 115/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9603 - iou_coef: 0.3250 - dice_coef: 0.3463
# Epoch 00115: val_loss did not improve from 0.23911
# 579/579 [==============================] - 573s 990ms/step - loss: 0.1178 - accuracy: 0.9604 - iou_coef: 0.3250 - dice_coef: 0.3462 - val_loss: 0.4005 - val_accuracy: 0.8776 - val_iou_coef: 0.3726 - val_dice_coef: 0.4133
# Epoch 116/500
# 578/579 [============================>.] - ETA: 0s - loss: 0.